# %%
# %matplotlib inline

from typing import Optional, Union

import os
import sys
import wget
import argparse

import torch
import torchvision
from torch import Tensor
import torch.nn.functional as F
from torchvision.ops import boxes as box_ops
from torchvision.ops.boxes import box_area
from torchvision.ops.roi_align import _bilinear_interpolate, roi_align
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

import numpy as np
import matplotlib.pyplot as plt

sys.path.append('../../../')
from computer_vision.mask_rcnn.dataset.penn_fudan_ped import PennFudanDataset, get_transform


torch.manual_seed(0)
np.random.seed(0)

# %%
# Create the parser
parser = argparse.ArgumentParser(description='MaskRCNN')

# Add arguments
parser.add_argument('--rpn-objectness-weight', type=float, default=10., help='weight to the loss of RPN objectness')
parser.add_argument('--rpn-box-regression-weight', type=float, default=50., help='weight to the loss of RPN box regression')
parser.add_argument('--roi-classifier-weight', type=float, default=1., help='weight to the loss of roi-head for object class')
parser.add_argument('--roi-box-regression-weight', type=float, default=5., help='weight to the loss for roi-head box regression')
parser.add_argument('--mask-weight', type=float, default=0.5, help='weight to mask loss')
parser.add_argument('--n-training', type=int, default=160, help='number of training data')
parser.add_argument('--max-epochs', type=int, default=160, help='maximum number of epochs')
parser.add_argument('--print-freq', type=int, default=5, help='how many batch before printing')

args = parser.parse_args('--max-epochs 50  --print-freq 20'.split())
args
# Out:
# Namespace(rpn_objectness_weight=10.0, rpn_box_regression_weight=50.0, roi_classifier_weight=1.0, roi_box_regression_weight=5.0, mask_weight=0.5, n_training=160, max_epochs=50, print_freq=20)

# %%
device=torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print('device ', device)

main_dirpath='D:/data/'
output_dirpath='D:/results/mask_rcnn'
if not os.path.isdir(output_dirpath): os.makedirs(output_dirpath)
# Out:
# device  cuda

# %%
main_url='https://raw.githubusercontent.com/pytorch/vision/main/references/detection'
for file in ['engine.py', 'utils.py','coco_utils.py','coco_eval.py', 'transforms.py']:
    if os.path.isfile(file): continue
    out=wget.download(url=f'{main_url}/{file}', out=None)
    print(file, out)

import utils

# %%
data_url='https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip'
wget.download(url=data_url, out=main_dirpath)
# Out:
# 100% [................................................] 53723336 / 53723336
# 'D:/data//PennFudanPed (1).zip'

# %%
num_classes=2
# load an instance segmentation model pre-trained on COCO
model=torchvision.models.detection.maskrcnn_resnet50_fpn_v2(weights='DEFAULT', rpn_pre_nms_top_n_train=800,
        rpn_pre_nms_top_n_test=500,  rpn_post_nms_top_n_train=800,  rpn_post_nms_top_n_test=500, box_detections_per_img=100,
        box_batch_size_per_image =400, rpn_batch_size_per_image=100)
# get number of input features for the classifier
in_features=model.roi_heads.box_predictor.cls_score.in_features
print('the number of inpute features for classifiers ', in_features)
# replace the pre-trained head with a new one
model.roi_heads.box_predictor=FastRCNNPredictor(in_features,  num_classes)

# get the number of input features for the mask classifiers
in_features_mask=model.roi_heads.mask_predictor.conv5_mask.in_channels
print('the number of input features for mask ', in_features_mask)
hidden_layer=256
# and replace the mask predictor with a new one
model.roi_heads.mask_predictor=MaskRCNNPredictor(in_features_mask, hidden_layer, num_classes)

# move model to the right device
model.to(device);

optimizer=torch.optim.AdamW(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
# Out:
# the number of inpute features for classifiers  1024
# the number of input features for mask  256

# %%
# there are 170 images
train_dataset=PennFudanDataset(root=os.path.join(main_dirpath, 'PennFudanPed'), image_dirname='PNGImages', mask_dirname='PedMasks',
                               annotation_dirname='Annotation', transforms=get_transform(is_train=True), indices=np.arange(160))
val_dataset=PennFudanDataset(root=os.path.join(main_dirpath, 'PennFudanPed'), image_dirname='PNGImages', mask_dirname='PedMasks',
                               annotation_dirname='Annotation', transforms=get_transform(is_train=False), indices=np.arange(160,170))
print('train_dataset ', len(train_dataset), ' val_dataset ', len(val_dataset))
# define training and validation data loaders
train_loader=torch.utils.data.DataLoader(train_dataset, batch_size=2,shuffle=True,collate_fn=utils.collate_fn)
val_loader=torch.utils.data.DataLoader(val_dataset, batch_size=2,shuffle=False,collate_fn=utils.collate_fn)
# Out:
# train_dataset  160  val_dataset  10

# %%
def train_epoch(model, train_loader, optimizer,weights, device, print_freq=1):

    running_loss=0.
    for i, (images, targets) in enumerate(train_loader, 1):
        # port data to device
        images=[im.to(device) for im in images]
        targets=[{k:v.to(device) if isinstance(v, torch.Tensor) else v for k, v in target.items()} for target in targets]

        # zero gradients
        optimizer.zero_grad()

        # estimate
        outputs=model(images, targets)

        # compute loss
        loss, log=0., ''
        for name, loss_term in outputs.items():
            loss+=weights[name]*loss_term
            log+=f' {name}:{loss.item():.3f},'
        loss.backward()

        # adjusting parameters
        optimizer.step()

        # gather data and report
        running_loss+=loss.item()
        if print_freq>0 and i%print_freq==0:
            print(f'\tIteration {i} [{100*i/len(train_loader):.2f}%]: total:{loss.item():.3f}, {log}')
    last_loss=running_loss/len(train_loader)
    return last_loss

def validation(model, val_loader, weights, device):
    running_loss, loss_per_task=0., dict()
    for i, (images, targets) in enumerate(val_loader, 1):

        # port data to device
        images=[im.to(device) for im in images]
        targets=[{k:v.to(device) if isinstance(v, torch.Tensor) else v for k, v in target.items()} for target in targets]

        with torch.no_grad(): outputs=model(images, targets)
        # compute loss
        loss=0
        for name, loss_term in outputs.items():
            loss+=weights[name]*loss_term
            if name not in loss_per_task: loss_per_task[name]=0.
            loss_per_task[name]+=loss_term.item()
        running_loss+=loss.item()
        break
    loss/=len(val_loader)
    loss_per_task={k:n/len(val_loader) for k, n in loss_per_task.items()}
    return loss, loss_per_task

# %%
weights={'loss_classifier':args.roi_classifier_weight, 'loss_box_reg':args.roi_box_regression_weight,
         'loss_mask':args.mask_weight,'loss_objectness':args.rpn_objectness_weight,
         'loss_rpn_box_reg':args.rpn_box_regression_weight}

model.train()
best_vloss=np.inf
train_losses, val_losses=[],[]
for epoch in range(1, args.max_epochs+1):
    # make sure gradient tracking is on
    t_loss=train_epoch(model, train_loader, optimizer, weights=weights, device=device, print_freq=args.print_freq)

    # validation
    v_loss, v_loss_per_task=validation(model, val_loader, weights=weights, device=device)

    # record training measures
    train_losses+=[t_loss]
    val_losses+=[v_loss.cpu()]

    # print progress
    log=''
    for k, v in v_loss_per_task.items(): log+=f' {k}:{v:.2f},'
    print(f'Epoch {epoch} [{100.*epoch/args.max_epochs}:.2f]: training loss {t_loss:.3f}, val_loss: {v_loss:.3f}, {log}')

    if v_loss<best_vloss and epoch>1:
        best_vloss=v_loss
        torch.save(model.state_dict(), os.path.join(output_dirpath, 'best_checkpoint.pth'))

    torch.save(model.state_dict(), os.path.join(output_dirpath,'checkpoint.pth'))
# Out:
# 	Iteration 20 [25.00%]: total:4.266,  loss_classifier:0.218, loss_box_reg:1.274, loss_mask:1.603, loss_objectness:2.013, loss_rpn_box_reg:4.266,
# 	Iteration 40 [50.00%]: total:1.277,  loss_classifier:0.089, loss_box_reg:0.337, loss_mask:0.647, loss_objectness:0.939, loss_rpn_box_reg:1.277,
# 	Iteration 60 [75.00%]: total:1.969,  loss_classifier:0.103, loss_box_reg:0.447, loss_mask:0.699, loss_objectness:0.988, loss_rpn_box_reg:1.969,
# 	Iteration 80 [100.00%]: total:7.024,  loss_classifier:0.186, loss_box_reg:1.289, loss_mask:1.561, loss_objectness:1.687, loss_rpn_box_reg:7.024,
# Epoch 1 [2.0:.2f]: training loss 4.807, val_loss: 0.334,  loss_classifier:0.02, loss_box_reg:0.02, loss_mask:0.12, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:4.070,  loss_classifier:0.115, loss_box_reg:0.777, loss_mask:1.048, loss_objectness:1.238, loss_rpn_box_reg:4.070,
# 	Iteration 40 [50.00%]: total:1.741,  loss_classifier:0.081, loss_box_reg:0.379, loss_mask:0.629, loss_objectness:0.930, loss_rpn_box_reg:1.741,
# 	Iteration 60 [75.00%]: total:2.044,  loss_classifier:0.140, loss_box_reg:0.645, loss_mask:0.902, loss_objectness:1.008, loss_rpn_box_reg:2.044,
# 	Iteration 80 [100.00%]: total:6.053,  loss_classifier:0.127, loss_box_reg:1.023, loss_mask:1.232, loss_objectness:1.576, loss_rpn_box_reg:6.053,
# Epoch 2 [4.0:.2f]: training loss 4.301, val_loss: 0.306,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.11, loss_objectness:0.01, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:2.778,  loss_classifier:0.081, loss_box_reg:0.378, loss_mask:0.605, loss_objectness:0.873, loss_rpn_box_reg:2.778,
# 	Iteration 40 [50.00%]: total:5.656,  loss_classifier:0.102, loss_box_reg:0.737, loss_mask:0.958, loss_objectness:1.046, loss_rpn_box_reg:5.656,
# 	Iteration 60 [75.00%]: total:2.071,  loss_classifier:0.077, loss_box_reg:0.358, loss_mask:0.639, loss_objectness:1.054, loss_rpn_box_reg:2.071,
# 	Iteration 80 [100.00%]: total:2.764,  loss_classifier:0.124, loss_box_reg:0.708, loss_mask:0.919, loss_objectness:0.980, loss_rpn_box_reg:2.764,
# Epoch 3 [6.0:.2f]: training loss 3.887, val_loss: 0.334,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.09, loss_objectness:0.01, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:2.653,  loss_classifier:0.096, loss_box_reg:0.746, loss_mask:0.952, loss_objectness:1.284, loss_rpn_box_reg:2.653,
# 	Iteration 40 [50.00%]: total:1.790,  loss_classifier:0.068, loss_box_reg:0.442, loss_mask:0.605, loss_objectness:0.751, loss_rpn_box_reg:1.790,
# 	Iteration 60 [75.00%]: total:2.020,  loss_classifier:0.070, loss_box_reg:0.514, loss_mask:0.659, loss_objectness:0.900, loss_rpn_box_reg:2.020,
# 	Iteration 80 [100.00%]: total:1.719,  loss_classifier:0.059, loss_box_reg:0.278, loss_mask:0.468, loss_objectness:1.019, loss_rpn_box_reg:1.719,
# Epoch 4 [8.0:.2f]: training loss 3.669, val_loss: 0.275,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.12, loss_objectness:0.01, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:4.958,  loss_classifier:0.175, loss_box_reg:1.123, loss_mask:1.337, loss_objectness:1.374, loss_rpn_box_reg:4.958,
# 	Iteration 40 [50.00%]: total:1.980,  loss_classifier:0.046, loss_box_reg:0.325, loss_mask:0.508, loss_objectness:0.546, loss_rpn_box_reg:1.980,
# 	Iteration 60 [75.00%]: total:3.493,  loss_classifier:0.100, loss_box_reg:0.755, loss_mask:0.974, loss_objectness:1.088, loss_rpn_box_reg:3.493,
# 	Iteration 80 [100.00%]: total:5.888,  loss_classifier:0.111, loss_box_reg:0.949, loss_mask:1.199, loss_objectness:1.430, loss_rpn_box_reg:5.888,
# Epoch 5 [10.0:.2f]: training loss 3.995, val_loss: 0.222,  loss_classifier:0.02, loss_box_reg:0.01, loss_mask:0.10, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:6.186,  loss_classifier:0.158, loss_box_reg:1.230, loss_mask:1.485, loss_objectness:1.798, loss_rpn_box_reg:6.186,
# 	Iteration 40 [50.00%]: total:4.311,  loss_classifier:0.135, loss_box_reg:0.749, loss_mask:1.004, loss_objectness:2.695, loss_rpn_box_reg:4.311,
# 	Iteration 60 [75.00%]: total:1.178,  loss_classifier:0.065, loss_box_reg:0.379, loss_mask:0.603, loss_objectness:0.696, loss_rpn_box_reg:1.178,
# 	Iteration 80 [100.00%]: total:3.535,  loss_classifier:0.090, loss_box_reg:0.806, loss_mask:1.022, loss_objectness:1.368, loss_rpn_box_reg:3.535,
# Epoch 6 [12.0:.2f]: training loss 3.970, val_loss: 0.255,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.09, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:4.919,  loss_classifier:0.100, loss_box_reg:0.928, loss_mask:1.142, loss_objectness:1.393, loss_rpn_box_reg:4.919,
# 	Iteration 40 [50.00%]: total:3.426,  loss_classifier:0.157, loss_box_reg:1.258, loss_mask:1.492, loss_objectness:1.562, loss_rpn_box_reg:3.426,
# 	Iteration 60 [75.00%]: total:5.745,  loss_classifier:0.160, loss_box_reg:0.978, loss_mask:1.207, loss_objectness:1.252, loss_rpn_box_reg:5.745,
# 	Iteration 80 [100.00%]: total:2.095,  loss_classifier:0.103, loss_box_reg:0.648, loss_mask:0.855, loss_objectness:0.910, loss_rpn_box_reg:2.095,
# Epoch 7 [14.0:.2f]: training loss 3.448, val_loss: 0.175,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.07, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:4.878,  loss_classifier:0.140, loss_box_reg:1.012, loss_mask:1.248, loss_objectness:1.330, loss_rpn_box_reg:4.878,
# 	Iteration 40 [50.00%]: total:2.789,  loss_classifier:0.079, loss_box_reg:0.578, loss_mask:0.752, loss_objectness:0.772, loss_rpn_box_reg:2.789,
# 	Iteration 60 [75.00%]: total:3.422,  loss_classifier:0.110, loss_box_reg:1.024, loss_mask:1.193, loss_objectness:1.338, loss_rpn_box_reg:3.422,
# 	Iteration 80 [100.00%]: total:2.983,  loss_classifier:0.052, loss_box_reg:0.415, loss_mask:0.604, loss_objectness:0.686, loss_rpn_box_reg:2.983,
# Epoch 8 [16.0:.2f]: training loss 3.397, val_loss: 0.277,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.07, loss_objectness:0.01, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.756,  loss_classifier:0.062, loss_box_reg:0.377, loss_mask:0.563, loss_objectness:0.598, loss_rpn_box_reg:1.756,
# 	Iteration 40 [50.00%]: total:6.758,  loss_classifier:0.080, loss_box_reg:0.738, loss_mask:0.897, loss_objectness:1.354, loss_rpn_box_reg:6.758,
# 	Iteration 60 [75.00%]: total:3.351,  loss_classifier:0.106, loss_box_reg:0.755, loss_mask:0.923, loss_objectness:1.367, loss_rpn_box_reg:3.351,
# 	Iteration 80 [100.00%]: total:3.453,  loss_classifier:0.112, loss_box_reg:0.812, loss_mask:0.999, loss_objectness:1.175, loss_rpn_box_reg:3.453,
# Epoch 9 [18.0:.2f]: training loss 3.184, val_loss: 0.256,  loss_classifier:0.02, loss_box_reg:0.01, loss_mask:0.07, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.772,  loss_classifier:0.066, loss_box_reg:0.352, loss_mask:0.552, loss_objectness:0.705, loss_rpn_box_reg:1.772,
# 	Iteration 40 [50.00%]: total:3.598,  loss_classifier:0.171, loss_box_reg:1.090, loss_mask:1.250, loss_objectness:1.447, loss_rpn_box_reg:3.598,
# 	Iteration 60 [75.00%]: total:2.925,  loss_classifier:0.083, loss_box_reg:0.604, loss_mask:0.769, loss_objectness:1.037, loss_rpn_box_reg:2.925,
# 	Iteration 80 [100.00%]: total:2.860,  loss_classifier:0.095, loss_box_reg:0.632, loss_mask:0.850, loss_objectness:1.037, loss_rpn_box_reg:2.860,
# Epoch 10 [20.0:.2f]: training loss 3.074, val_loss: 0.330,  loss_classifier:0.02, loss_box_reg:0.02, loss_mask:0.06, loss_objectness:0.01, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:2.224,  loss_classifier:0.072, loss_box_reg:0.409, loss_mask:0.530, loss_objectness:0.545, loss_rpn_box_reg:2.224,
# 	Iteration 40 [50.00%]: total:5.546,  loss_classifier:0.106, loss_box_reg:0.932, loss_mask:1.088, loss_objectness:1.356, loss_rpn_box_reg:5.546,
# 	Iteration 60 [75.00%]: total:7.610,  loss_classifier:0.061, loss_box_reg:0.637, loss_mask:0.786, loss_objectness:0.893, loss_rpn_box_reg:7.610,
# 	Iteration 80 [100.00%]: total:2.118,  loss_classifier:0.075, loss_box_reg:0.642, loss_mask:0.804, loss_objectness:1.053, loss_rpn_box_reg:2.118,
# Epoch 11 [22.0:.2f]: training loss 3.012, val_loss: 0.244,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.07, loss_objectness:0.01, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:0.947,  loss_classifier:0.071, loss_box_reg:0.335, loss_mask:0.484, loss_objectness:0.515, loss_rpn_box_reg:0.947,
# 	Iteration 40 [50.00%]: total:4.151,  loss_classifier:0.096, loss_box_reg:0.791, loss_mask:0.945, loss_objectness:1.031, loss_rpn_box_reg:4.151,
# 	Iteration 60 [75.00%]: total:0.825,  loss_classifier:0.030, loss_box_reg:0.212, loss_mask:0.368, loss_objectness:0.403, loss_rpn_box_reg:0.825,
# 	Iteration 80 [100.00%]: total:4.915,  loss_classifier:0.146, loss_box_reg:1.313, loss_mask:1.525, loss_objectness:1.918, loss_rpn_box_reg:4.915,
# Epoch 12 [24.0:.2f]: training loss 2.843, val_loss: 0.186,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:2.140,  loss_classifier:0.109, loss_box_reg:0.827, loss_mask:1.001, loss_objectness:1.011, loss_rpn_box_reg:2.140,
# 	Iteration 40 [50.00%]: total:1.407,  loss_classifier:0.044, loss_box_reg:0.398, loss_mask:0.500, loss_objectness:0.598, loss_rpn_box_reg:1.407,
# 	Iteration 60 [75.00%]: total:2.249,  loss_classifier:0.107, loss_box_reg:0.731, loss_mask:0.965, loss_objectness:1.052, loss_rpn_box_reg:2.249,
# 	Iteration 80 [100.00%]: total:1.255,  loss_classifier:0.070, loss_box_reg:0.359, loss_mask:0.516, loss_objectness:0.643, loss_rpn_box_reg:1.255,
# Epoch 13 [26.0:.2f]: training loss 2.860, val_loss: 0.251,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.06, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:6.470,  loss_classifier:0.170, loss_box_reg:0.825, loss_mask:0.966, loss_objectness:2.283, loss_rpn_box_reg:6.470,
# 	Iteration 40 [50.00%]: total:0.714,  loss_classifier:0.037, loss_box_reg:0.309, loss_mask:0.429, loss_objectness:0.455, loss_rpn_box_reg:0.714,
# 	Iteration 60 [75.00%]: total:1.994,  loss_classifier:0.127, loss_box_reg:0.787, loss_mask:0.941, loss_objectness:1.286, loss_rpn_box_reg:1.994,
# 	Iteration 80 [100.00%]: total:1.705,  loss_classifier:0.055, loss_box_reg:0.359, loss_mask:0.490, loss_objectness:0.627, loss_rpn_box_reg:1.705,
# Epoch 14 [28.0:.2f]: training loss 2.742, val_loss: 0.196,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.06, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:2.084,  loss_classifier:0.094, loss_box_reg:0.620, loss_mask:0.839, loss_objectness:1.009, loss_rpn_box_reg:2.084,
# 	Iteration 40 [50.00%]: total:1.519,  loss_classifier:0.100, loss_box_reg:0.523, loss_mask:0.636, loss_objectness:0.665, loss_rpn_box_reg:1.519,
# 	Iteration 60 [75.00%]: total:2.922,  loss_classifier:0.082, loss_box_reg:0.784, loss_mask:0.895, loss_objectness:1.031, loss_rpn_box_reg:2.922,
# 	Iteration 80 [100.00%]: total:5.679,  loss_classifier:0.060, loss_box_reg:0.411, loss_mask:0.541, loss_objectness:0.589, loss_rpn_box_reg:5.679,
# Epoch 15 [30.0:.2f]: training loss 2.633, val_loss: 0.155,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.06, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.140,  loss_classifier:0.072, loss_box_reg:0.428, loss_mask:0.577, loss_objectness:0.577, loss_rpn_box_reg:1.140,
# 	Iteration 40 [50.00%]: total:0.544,  loss_classifier:0.029, loss_box_reg:0.224, loss_mask:0.350, loss_objectness:0.457, loss_rpn_box_reg:0.544,
# 	Iteration 60 [75.00%]: total:5.306,  loss_classifier:0.144, loss_box_reg:0.800, loss_mask:0.942, loss_objectness:1.367, loss_rpn_box_reg:5.306,
# 	Iteration 80 [100.00%]: total:2.623,  loss_classifier:0.099, loss_box_reg:0.769, loss_mask:0.931, loss_objectness:1.005, loss_rpn_box_reg:2.623,
# Epoch 16 [32.0:.2f]: training loss 2.544, val_loss: 0.131,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:0.646,  loss_classifier:0.048, loss_box_reg:0.230, loss_mask:0.349, loss_objectness:0.351, loss_rpn_box_reg:0.646,
# 	Iteration 40 [50.00%]: total:3.710,  loss_classifier:0.112, loss_box_reg:0.992, loss_mask:1.161, loss_objectness:1.204, loss_rpn_box_reg:3.710,
# 	Iteration 60 [75.00%]: total:1.829,  loss_classifier:0.057, loss_box_reg:0.432, loss_mask:0.534, loss_objectness:0.734, loss_rpn_box_reg:1.829,
# 	Iteration 80 [100.00%]: total:1.726,  loss_classifier:0.060, loss_box_reg:0.350, loss_mask:0.508, loss_objectness:0.809, loss_rpn_box_reg:1.726,
# Epoch 17 [34.0:.2f]: training loss 2.370, val_loss: 0.187,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.356,  loss_classifier:0.049, loss_box_reg:0.418, loss_mask:0.543, loss_objectness:0.714, loss_rpn_box_reg:1.356,
# 	Iteration 40 [50.00%]: total:3.450,  loss_classifier:0.045, loss_box_reg:0.513, loss_mask:0.620, loss_objectness:0.717, loss_rpn_box_reg:3.450,
# 	Iteration 60 [75.00%]: total:4.121,  loss_classifier:0.083, loss_box_reg:0.877, loss_mask:0.999, loss_objectness:1.048, loss_rpn_box_reg:4.121,
# 	Iteration 80 [100.00%]: total:0.712,  loss_classifier:0.031, loss_box_reg:0.275, loss_mask:0.351, loss_objectness:0.405, loss_rpn_box_reg:0.712,
# Epoch 18 [36.0:.2f]: training loss 2.298, val_loss: 0.177,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.06, loss_objectness:0.01, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.322,  loss_classifier:0.062, loss_box_reg:0.421, loss_mask:0.566, loss_objectness:0.574, loss_rpn_box_reg:1.322,
# 	Iteration 40 [50.00%]: total:2.850,  loss_classifier:0.075, loss_box_reg:0.709, loss_mask:0.832, loss_objectness:1.229, loss_rpn_box_reg:2.850,
# 	Iteration 60 [75.00%]: total:2.665,  loss_classifier:0.159, loss_box_reg:1.026, loss_mask:1.242, loss_objectness:1.423, loss_rpn_box_reg:2.665,
# 	Iteration 80 [100.00%]: total:1.330,  loss_classifier:0.057, loss_box_reg:0.387, loss_mask:0.499, loss_objectness:0.584, loss_rpn_box_reg:1.330,
# Epoch 19 [38.0:.2f]: training loss 2.321, val_loss: 0.242,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.06, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.780,  loss_classifier:0.141, loss_box_reg:0.718, loss_mask:0.861, loss_objectness:0.967, loss_rpn_box_reg:1.780,
# 	Iteration 40 [50.00%]: total:2.164,  loss_classifier:0.064, loss_box_reg:0.512, loss_mask:0.638, loss_objectness:0.983, loss_rpn_box_reg:2.164,
# 	Iteration 60 [75.00%]: total:0.914,  loss_classifier:0.061, loss_box_reg:0.341, loss_mask:0.488, loss_objectness:0.611, loss_rpn_box_reg:0.914,
# 	Iteration 80 [100.00%]: total:1.822,  loss_classifier:0.046, loss_box_reg:0.423, loss_mask:0.555, loss_objectness:0.571, loss_rpn_box_reg:1.822,
# Epoch 20 [40.0:.2f]: training loss 2.131, val_loss: 0.180,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.072,  loss_classifier:0.038, loss_box_reg:0.229, loss_mask:0.312, loss_objectness:0.315, loss_rpn_box_reg:1.072,
# 	Iteration 40 [50.00%]: total:1.744,  loss_classifier:0.092, loss_box_reg:0.790, loss_mask:0.917, loss_objectness:1.015, loss_rpn_box_reg:1.744,
# 	Iteration 60 [75.00%]: total:1.178,  loss_classifier:0.056, loss_box_reg:0.325, loss_mask:0.422, loss_objectness:0.439, loss_rpn_box_reg:1.178,
# 	Iteration 80 [100.00%]: total:4.671,  loss_classifier:0.131, loss_box_reg:1.136, loss_mask:1.298, loss_objectness:1.331, loss_rpn_box_reg:4.671,
# Epoch 21 [42.0:.2f]: training loss 2.287, val_loss: 0.172,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.860,  loss_classifier:0.052, loss_box_reg:0.319, loss_mask:0.423, loss_objectness:0.431, loss_rpn_box_reg:1.860,
# 	Iteration 40 [50.00%]: total:1.395,  loss_classifier:0.055, loss_box_reg:0.484, loss_mask:0.565, loss_objectness:0.571, loss_rpn_box_reg:1.395,
# 	Iteration 60 [75.00%]: total:1.128,  loss_classifier:0.049, loss_box_reg:0.387, loss_mask:0.486, loss_objectness:0.598, loss_rpn_box_reg:1.128,
# 	Iteration 80 [100.00%]: total:1.704,  loss_classifier:0.053, loss_box_reg:0.506, loss_mask:0.612, loss_objectness:0.694, loss_rpn_box_reg:1.704,
# Epoch 22 [44.0:.2f]: training loss 2.182, val_loss: 0.188,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:5.492,  loss_classifier:0.083, loss_box_reg:0.762, loss_mask:0.857, loss_objectness:0.897, loss_rpn_box_reg:5.492,
# 	Iteration 40 [50.00%]: total:2.068,  loss_classifier:0.067, loss_box_reg:0.583, loss_mask:0.683, loss_objectness:0.747, loss_rpn_box_reg:2.068,
# 	Iteration 60 [75.00%]: total:3.021,  loss_classifier:0.077, loss_box_reg:0.698, loss_mask:0.873, loss_objectness:1.426, loss_rpn_box_reg:3.021,
# 	Iteration 80 [100.00%]: total:2.259,  loss_classifier:0.074, loss_box_reg:0.576, loss_mask:0.708, loss_objectness:0.792, loss_rpn_box_reg:2.259,
# Epoch 23 [46.0:.2f]: training loss 2.129, val_loss: 0.238,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.01, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:3.617,  loss_classifier:0.095, loss_box_reg:0.897, loss_mask:1.078, loss_objectness:1.092, loss_rpn_box_reg:3.617,
# 	Iteration 40 [50.00%]: total:2.220,  loss_classifier:0.054, loss_box_reg:0.674, loss_mask:0.787, loss_objectness:0.790, loss_rpn_box_reg:2.220,
# 	Iteration 60 [75.00%]: total:1.959,  loss_classifier:0.063, loss_box_reg:0.462, loss_mask:0.596, loss_objectness:0.608, loss_rpn_box_reg:1.959,
# 	Iteration 80 [100.00%]: total:3.066,  loss_classifier:0.107, loss_box_reg:0.830, loss_mask:1.036, loss_objectness:1.187, loss_rpn_box_reg:3.066,
# Epoch 24 [48.0:.2f]: training loss 2.120, val_loss: 0.130,  loss_classifier:0.00, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:2.566,  loss_classifier:0.053, loss_box_reg:0.460, loss_mask:0.552, loss_objectness:0.565, loss_rpn_box_reg:2.566,
# 	Iteration 40 [50.00%]: total:3.645,  loss_classifier:0.134, loss_box_reg:1.133, loss_mask:1.259, loss_objectness:1.306, loss_rpn_box_reg:3.645,
# 	Iteration 60 [75.00%]: total:0.997,  loss_classifier:0.046, loss_box_reg:0.264, loss_mask:0.385, loss_objectness:0.591, loss_rpn_box_reg:0.997,
# 	Iteration 80 [100.00%]: total:1.056,  loss_classifier:0.015, loss_box_reg:0.068, loss_mask:0.163, loss_objectness:0.255, loss_rpn_box_reg:1.056,
# Epoch 25 [50.0:.2f]: training loss 2.068, val_loss: 0.186,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:0.685,  loss_classifier:0.070, loss_box_reg:0.261, loss_mask:0.420, loss_objectness:0.451, loss_rpn_box_reg:0.685,
# 	Iteration 40 [50.00%]: total:3.404,  loss_classifier:0.103, loss_box_reg:0.835, loss_mask:0.965, loss_objectness:0.985, loss_rpn_box_reg:3.404,
# 	Iteration 60 [75.00%]: total:1.534,  loss_classifier:0.074, loss_box_reg:0.664, loss_mask:0.782, loss_objectness:0.823, loss_rpn_box_reg:1.534,
# 	Iteration 80 [100.00%]: total:0.832,  loss_classifier:0.053, loss_box_reg:0.404, loss_mask:0.525, loss_objectness:0.533, loss_rpn_box_reg:0.832,
# Epoch 26 [52.0:.2f]: training loss 2.048, val_loss: 0.141,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.274,  loss_classifier:0.061, loss_box_reg:0.393, loss_mask:0.515, loss_objectness:0.609, loss_rpn_box_reg:1.274,
# 	Iteration 40 [50.00%]: total:2.595,  loss_classifier:0.082, loss_box_reg:0.591, loss_mask:0.776, loss_objectness:0.925, loss_rpn_box_reg:2.595,
# 	Iteration 60 [75.00%]: total:3.115,  loss_classifier:0.092, loss_box_reg:0.919, loss_mask:1.100, loss_objectness:1.277, loss_rpn_box_reg:3.115,
# 	Iteration 80 [100.00%]: total:2.185,  loss_classifier:0.050, loss_box_reg:0.508, loss_mask:0.612, loss_objectness:0.629, loss_rpn_box_reg:2.185,
# Epoch 27 [54.0:.2f]: training loss 2.081, val_loss: 0.192,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:0.787,  loss_classifier:0.042, loss_box_reg:0.353, loss_mask:0.463, loss_objectness:0.580, loss_rpn_box_reg:0.787,
# 	Iteration 40 [50.00%]: total:2.316,  loss_classifier:0.066, loss_box_reg:0.473, loss_mask:0.655, loss_objectness:0.675, loss_rpn_box_reg:2.316,
# 	Iteration 60 [75.00%]: total:1.680,  loss_classifier:0.069, loss_box_reg:0.395, loss_mask:0.507, loss_objectness:0.512, loss_rpn_box_reg:1.680,
# 	Iteration 80 [100.00%]: total:1.547,  loss_classifier:0.078, loss_box_reg:0.598, loss_mask:0.682, loss_objectness:0.706, loss_rpn_box_reg:1.547,
# Epoch 28 [56.0:.2f]: training loss 2.035, val_loss: 0.227,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.142,  loss_classifier:0.056, loss_box_reg:0.349, loss_mask:0.505, loss_objectness:0.843, loss_rpn_box_reg:1.142,
# 	Iteration 40 [50.00%]: total:1.227,  loss_classifier:0.044, loss_box_reg:0.286, loss_mask:0.423, loss_objectness:0.455, loss_rpn_box_reg:1.227,
# 	Iteration 60 [75.00%]: total:0.799,  loss_classifier:0.062, loss_box_reg:0.476, loss_mask:0.598, loss_objectness:0.605, loss_rpn_box_reg:0.799,
# 	Iteration 80 [100.00%]: total:1.384,  loss_classifier:0.079, loss_box_reg:0.462, loss_mask:0.609, loss_objectness:0.646, loss_rpn_box_reg:1.384,
# Epoch 29 [58.0:.2f]: training loss 1.873, val_loss: 0.113,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.623,  loss_classifier:0.046, loss_box_reg:0.336, loss_mask:0.448, loss_objectness:0.491, loss_rpn_box_reg:1.623,
# 	Iteration 40 [50.00%]: total:1.192,  loss_classifier:0.063, loss_box_reg:0.460, loss_mask:0.618, loss_objectness:0.651, loss_rpn_box_reg:1.192,
# 	Iteration 60 [75.00%]: total:3.396,  loss_classifier:0.066, loss_box_reg:0.566, loss_mask:0.720, loss_objectness:0.806, loss_rpn_box_reg:3.396,
# 	Iteration 80 [100.00%]: total:1.924,  loss_classifier:0.056, loss_box_reg:0.449, loss_mask:0.572, loss_objectness:0.678, loss_rpn_box_reg:1.924,
# Epoch 30 [60.0:.2f]: training loss 1.861, val_loss: 0.133,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:0.789,  loss_classifier:0.028, loss_box_reg:0.278, loss_mask:0.347, loss_objectness:0.479, loss_rpn_box_reg:0.789,
# 	Iteration 40 [50.00%]: total:1.595,  loss_classifier:0.089, loss_box_reg:0.582, loss_mask:0.688, loss_objectness:0.714, loss_rpn_box_reg:1.595,
# 	Iteration 60 [75.00%]: total:1.689,  loss_classifier:0.056, loss_box_reg:0.410, loss_mask:0.551, loss_objectness:0.555, loss_rpn_box_reg:1.689,
# 	Iteration 80 [100.00%]: total:0.545,  loss_classifier:0.037, loss_box_reg:0.210, loss_mask:0.314, loss_objectness:0.321, loss_rpn_box_reg:0.545,
# Epoch 31 [62.0:.2f]: training loss 1.773, val_loss: 0.186,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:2.238,  loss_classifier:0.086, loss_box_reg:0.675, loss_mask:0.844, loss_objectness:1.008, loss_rpn_box_reg:2.238,
# 	Iteration 40 [50.00%]: total:1.291,  loss_classifier:0.050, loss_box_reg:0.403, loss_mask:0.513, loss_objectness:0.516, loss_rpn_box_reg:1.291,
# 	Iteration 60 [75.00%]: total:1.473,  loss_classifier:0.107, loss_box_reg:0.658, loss_mask:0.834, loss_objectness:0.922, loss_rpn_box_reg:1.473,
# 	Iteration 80 [100.00%]: total:2.134,  loss_classifier:0.072, loss_box_reg:0.713, loss_mask:0.884, loss_objectness:0.950, loss_rpn_box_reg:2.134,
# Epoch 32 [64.0:.2f]: training loss 2.124, val_loss: 0.273,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.06, loss_objectness:0.01, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.555,  loss_classifier:0.057, loss_box_reg:0.376, loss_mask:0.482, loss_objectness:0.609, loss_rpn_box_reg:1.555,
# 	Iteration 40 [50.00%]: total:2.048,  loss_classifier:0.050, loss_box_reg:0.461, loss_mask:0.557, loss_objectness:0.863, loss_rpn_box_reg:2.048,
# 	Iteration 60 [75.00%]: total:1.932,  loss_classifier:0.070, loss_box_reg:0.568, loss_mask:0.698, loss_objectness:0.749, loss_rpn_box_reg:1.932,
# 	Iteration 80 [100.00%]: total:1.141,  loss_classifier:0.050, loss_box_reg:0.393, loss_mask:0.533, loss_objectness:0.548, loss_rpn_box_reg:1.141,
# Epoch 33 [66.0:.2f]: training loss 2.017, val_loss: 0.140,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:3.252,  loss_classifier:0.106, loss_box_reg:0.783, loss_mask:0.908, loss_objectness:0.927, loss_rpn_box_reg:3.252,
# 	Iteration 40 [50.00%]: total:1.558,  loss_classifier:0.078, loss_box_reg:0.552, loss_mask:0.661, loss_objectness:0.696, loss_rpn_box_reg:1.558,
# 	Iteration 60 [75.00%]: total:1.680,  loss_classifier:0.089, loss_box_reg:0.668, loss_mask:0.791, loss_objectness:0.810, loss_rpn_box_reg:1.680,
# 	Iteration 80 [100.00%]: total:1.604,  loss_classifier:0.085, loss_box_reg:0.725, loss_mask:0.861, loss_objectness:0.894, loss_rpn_box_reg:1.604,
# Epoch 34 [68.0:.2f]: training loss 1.787, val_loss: 0.168,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:0.456,  loss_classifier:0.035, loss_box_reg:0.146, loss_mask:0.236, loss_objectness:0.258, loss_rpn_box_reg:0.456,
# 	Iteration 40 [50.00%]: total:0.947,  loss_classifier:0.052, loss_box_reg:0.310, loss_mask:0.439, loss_objectness:0.669, loss_rpn_box_reg:0.947,
# 	Iteration 60 [75.00%]: total:2.263,  loss_classifier:0.074, loss_box_reg:0.683, loss_mask:0.778, loss_objectness:0.791, loss_rpn_box_reg:2.263,
# 	Iteration 80 [100.00%]: total:1.581,  loss_classifier:0.047, loss_box_reg:0.321, loss_mask:0.415, loss_objectness:0.434, loss_rpn_box_reg:1.581,
# Epoch 35 [70.0:.2f]: training loss 1.691, val_loss: 0.146,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:0.611,  loss_classifier:0.043, loss_box_reg:0.297, loss_mask:0.389, loss_objectness:0.416, loss_rpn_box_reg:0.611,
# 	Iteration 40 [50.00%]: total:0.645,  loss_classifier:0.034, loss_box_reg:0.208, loss_mask:0.304, loss_objectness:0.470, loss_rpn_box_reg:0.645,
# 	Iteration 60 [75.00%]: total:1.151,  loss_classifier:0.035, loss_box_reg:0.340, loss_mask:0.424, loss_objectness:0.469, loss_rpn_box_reg:1.151,
# 	Iteration 80 [100.00%]: total:1.938,  loss_classifier:0.058, loss_box_reg:0.399, loss_mask:0.545, loss_objectness:0.701, loss_rpn_box_reg:1.938,
# Epoch 36 [72.0:.2f]: training loss 1.567, val_loss: 0.135,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:3.439,  loss_classifier:0.051, loss_box_reg:0.503, loss_mask:0.601, loss_objectness:0.672, loss_rpn_box_reg:3.439,
# 	Iteration 40 [50.00%]: total:0.715,  loss_classifier:0.042, loss_box_reg:0.471, loss_mask:0.594, loss_objectness:0.596, loss_rpn_box_reg:0.715,
# 	Iteration 60 [75.00%]: total:1.115,  loss_classifier:0.045, loss_box_reg:0.269, loss_mask:0.356, loss_objectness:0.365, loss_rpn_box_reg:1.115,
# 	Iteration 80 [100.00%]: total:2.192,  loss_classifier:0.051, loss_box_reg:0.570, loss_mask:0.690, loss_objectness:0.700, loss_rpn_box_reg:2.192,
# Epoch 37 [74.0:.2f]: training loss 1.550, val_loss: 0.144,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:0.549,  loss_classifier:0.041, loss_box_reg:0.212, loss_mask:0.319, loss_objectness:0.373, loss_rpn_box_reg:0.549,
# 	Iteration 40 [50.00%]: total:1.589,  loss_classifier:0.048, loss_box_reg:0.460, loss_mask:0.549, loss_objectness:0.551, loss_rpn_box_reg:1.589,
# 	Iteration 60 [75.00%]: total:2.524,  loss_classifier:0.127, loss_box_reg:0.933, loss_mask:1.100, loss_objectness:1.109, loss_rpn_box_reg:2.524,
# 	Iteration 80 [100.00%]: total:1.722,  loss_classifier:0.051, loss_box_reg:0.472, loss_mask:0.559, loss_objectness:0.979, loss_rpn_box_reg:1.722,
# Epoch 38 [76.0:.2f]: training loss 1.558, val_loss: 0.151,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:2.418,  loss_classifier:0.087, loss_box_reg:0.774, loss_mask:0.922, loss_objectness:1.007, loss_rpn_box_reg:2.418,
# 	Iteration 40 [50.00%]: total:2.754,  loss_classifier:0.106, loss_box_reg:0.827, loss_mask:0.958, loss_objectness:1.059, loss_rpn_box_reg:2.754,
# 	Iteration 60 [75.00%]: total:0.704,  loss_classifier:0.024, loss_box_reg:0.152, loss_mask:0.237, loss_objectness:0.241, loss_rpn_box_reg:0.704,
# 	Iteration 80 [100.00%]: total:1.167,  loss_classifier:0.037, loss_box_reg:0.317, loss_mask:0.399, loss_objectness:0.611, loss_rpn_box_reg:1.167,
# Epoch 39 [78.0:.2f]: training loss 1.455, val_loss: 0.218,  loss_classifier:0.01, loss_box_reg:0.00, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:0.762,  loss_classifier:0.048, loss_box_reg:0.387, loss_mask:0.508, loss_objectness:0.529, loss_rpn_box_reg:0.762,
# 	Iteration 40 [50.00%]: total:0.509,  loss_classifier:0.043, loss_box_reg:0.315, loss_mask:0.420, loss_objectness:0.422, loss_rpn_box_reg:0.509,
# 	Iteration 60 [75.00%]: total:0.906,  loss_classifier:0.053, loss_box_reg:0.317, loss_mask:0.430, loss_objectness:0.445, loss_rpn_box_reg:0.906,
# 	Iteration 80 [100.00%]: total:1.742,  loss_classifier:0.053, loss_box_reg:0.490, loss_mask:0.576, loss_objectness:0.686, loss_rpn_box_reg:1.742,
# Epoch 40 [80.0:.2f]: training loss 1.468, val_loss: 0.220,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.01, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.256,  loss_classifier:0.066, loss_box_reg:0.573, loss_mask:0.655, loss_objectness:0.669, loss_rpn_box_reg:1.256,
# 	Iteration 40 [50.00%]: total:0.661,  loss_classifier:0.048, loss_box_reg:0.226, loss_mask:0.333, loss_objectness:0.346, loss_rpn_box_reg:0.661,
# 	Iteration 60 [75.00%]: total:2.199,  loss_classifier:0.058, loss_box_reg:0.630, loss_mask:0.731, loss_objectness:0.752, loss_rpn_box_reg:2.199,
# 	Iteration 80 [100.00%]: total:1.702,  loss_classifier:0.064, loss_box_reg:0.680, loss_mask:0.812, loss_objectness:0.947, loss_rpn_box_reg:1.702,
# Epoch 41 [82.0:.2f]: training loss 1.532, val_loss: 0.168,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:3.242,  loss_classifier:0.091, loss_box_reg:1.150, loss_mask:1.312, loss_objectness:1.677, loss_rpn_box_reg:3.242,
# 	Iteration 40 [50.00%]: total:1.238,  loss_classifier:0.011, loss_box_reg:0.155, loss_mask:0.227, loss_objectness:0.227, loss_rpn_box_reg:1.238,
# 	Iteration 60 [75.00%]: total:2.016,  loss_classifier:0.077, loss_box_reg:0.784, loss_mask:0.906, loss_objectness:0.939, loss_rpn_box_reg:2.016,
# 	Iteration 80 [100.00%]: total:1.996,  loss_classifier:0.054, loss_box_reg:0.572, loss_mask:0.649, loss_objectness:0.660, loss_rpn_box_reg:1.996,
# Epoch 42 [84.0:.2f]: training loss 1.552, val_loss: 0.145,  loss_classifier:0.00, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:2.221,  loss_classifier:0.081, loss_box_reg:0.742, loss_mask:0.866, loss_objectness:0.881, loss_rpn_box_reg:2.221,
# 	Iteration 40 [50.00%]: total:1.970,  loss_classifier:0.101, loss_box_reg:0.745, loss_mask:0.874, loss_objectness:0.886, loss_rpn_box_reg:1.970,
# 	Iteration 60 [75.00%]: total:3.903,  loss_classifier:0.155, loss_box_reg:1.233, loss_mask:1.398, loss_objectness:1.678, loss_rpn_box_reg:3.903,
# 	Iteration 80 [100.00%]: total:2.179,  loss_classifier:0.041, loss_box_reg:0.542, loss_mask:0.667, loss_objectness:0.681, loss_rpn_box_reg:2.179,
# Epoch 43 [86.0:.2f]: training loss 1.394, val_loss: 0.149,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:0.504,  loss_classifier:0.043, loss_box_reg:0.256, loss_mask:0.368, loss_objectness:0.370, loss_rpn_box_reg:0.504,
# 	Iteration 40 [50.00%]: total:1.775,  loss_classifier:0.073, loss_box_reg:0.611, loss_mask:0.727, loss_objectness:0.769, loss_rpn_box_reg:1.775,
# 	Iteration 60 [75.00%]: total:0.918,  loss_classifier:0.036, loss_box_reg:0.448, loss_mask:0.540, loss_objectness:0.557, loss_rpn_box_reg:0.918,
# 	Iteration 80 [100.00%]: total:1.036,  loss_classifier:0.053, loss_box_reg:0.475, loss_mask:0.604, loss_objectness:0.614, loss_rpn_box_reg:1.036,
# Epoch 44 [88.0:.2f]: training loss 1.308, val_loss: 0.117,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:0.679,  loss_classifier:0.035, loss_box_reg:0.309, loss_mask:0.376, loss_objectness:0.381, loss_rpn_box_reg:0.679,
# 	Iteration 40 [50.00%]: total:2.018,  loss_classifier:0.033, loss_box_reg:0.256, loss_mask:0.334, loss_objectness:0.346, loss_rpn_box_reg:2.018,
# 	Iteration 60 [75.00%]: total:0.680,  loss_classifier:0.024, loss_box_reg:0.244, loss_mask:0.317, loss_objectness:0.394, loss_rpn_box_reg:0.680,
# 	Iteration 80 [100.00%]: total:0.599,  loss_classifier:0.042, loss_box_reg:0.247, loss_mask:0.365, loss_objectness:0.367, loss_rpn_box_reg:0.599,
# Epoch 45 [90.0:.2f]: training loss 1.266, val_loss: 0.140,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.053,  loss_classifier:0.035, loss_box_reg:0.298, loss_mask:0.363, loss_objectness:0.364, loss_rpn_box_reg:1.053,
# 	Iteration 40 [50.00%]: total:1.834,  loss_classifier:0.078, loss_box_reg:0.550, loss_mask:0.657, loss_objectness:0.715, loss_rpn_box_reg:1.834,
# 	Iteration 60 [75.00%]: total:1.069,  loss_classifier:0.046, loss_box_reg:0.326, loss_mask:0.409, loss_objectness:0.685, loss_rpn_box_reg:1.069,
# 	Iteration 80 [100.00%]: total:1.344,  loss_classifier:0.069, loss_box_reg:0.562, loss_mask:0.648, loss_objectness:0.751, loss_rpn_box_reg:1.344,
# Epoch 46 [92.0:.2f]: training loss 1.211, val_loss: 0.169,  loss_classifier:0.00, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:2.068,  loss_classifier:0.060, loss_box_reg:0.542, loss_mask:0.653, loss_objectness:0.671, loss_rpn_box_reg:2.068,
# 	Iteration 40 [50.00%]: total:0.874,  loss_classifier:0.029, loss_box_reg:0.324, loss_mask:0.405, loss_objectness:0.413, loss_rpn_box_reg:0.874,
# 	Iteration 60 [75.00%]: total:2.454,  loss_classifier:0.076, loss_box_reg:0.574, loss_mask:0.680, loss_objectness:0.697, loss_rpn_box_reg:2.454,
# 	Iteration 80 [100.00%]: total:1.472,  loss_classifier:0.059, loss_box_reg:0.471, loss_mask:0.599, loss_objectness:0.607, loss_rpn_box_reg:1.472,
# Epoch 47 [94.0:.2f]: training loss 1.141, val_loss: 0.142,  loss_classifier:0.00, loss_box_reg:0.01, loss_mask:0.05, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.250,  loss_classifier:0.066, loss_box_reg:0.682, loss_mask:0.791, loss_objectness:0.803, loss_rpn_box_reg:1.250,
# 	Iteration 40 [50.00%]: total:2.211,  loss_classifier:0.055, loss_box_reg:0.674, loss_mask:0.792, loss_objectness:1.014, loss_rpn_box_reg:2.211,
# 	Iteration 60 [75.00%]: total:1.265,  loss_classifier:0.045, loss_box_reg:0.347, loss_mask:0.437, loss_objectness:0.728, loss_rpn_box_reg:1.265,
# 	Iteration 80 [100.00%]: total:2.132,  loss_classifier:0.110, loss_box_reg:0.826, loss_mask:0.938, loss_objectness:0.996, loss_rpn_box_reg:2.132,
# Epoch 48 [96.0:.2f]: training loss 1.132, val_loss: 0.117,  loss_classifier:0.00, loss_box_reg:0.00, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:1.430,  loss_classifier:0.066, loss_box_reg:0.664, loss_mask:0.761, loss_objectness:0.765, loss_rpn_box_reg:1.430,
# 	Iteration 40 [50.00%]: total:1.638,  loss_classifier:0.081, loss_box_reg:0.623, loss_mask:0.728, loss_objectness:0.755, loss_rpn_box_reg:1.638,
# 	Iteration 60 [75.00%]: total:0.437,  loss_classifier:0.022, loss_box_reg:0.174, loss_mask:0.252, loss_objectness:0.252, loss_rpn_box_reg:0.437,
# 	Iteration 80 [100.00%]: total:0.453,  loss_classifier:0.042, loss_box_reg:0.256, loss_mask:0.329, loss_objectness:0.358, loss_rpn_box_reg:0.453,
# Epoch 49 [98.0:.2f]: training loss 1.067, val_loss: 0.122,  loss_classifier:0.01, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,
# 	Iteration 20 [25.00%]: total:0.850,  loss_classifier:0.027, loss_box_reg:0.141, loss_mask:0.218, loss_objectness:0.222, loss_rpn_box_reg:0.850,
# 	Iteration 40 [50.00%]: total:1.095,  loss_classifier:0.059, loss_box_reg:0.459, loss_mask:0.581, loss_objectness:0.585, loss_rpn_box_reg:1.095,
# 	Iteration 60 [75.00%]: total:2.090,  loss_classifier:0.061, loss_box_reg:0.603, loss_mask:0.711, loss_objectness:0.832, loss_rpn_box_reg:2.090,
# 	Iteration 80 [100.00%]: total:0.985,  loss_classifier:0.074, loss_box_reg:0.479, loss_mask:0.604, loss_objectness:0.611, loss_rpn_box_reg:0.985,
# Epoch 50 [100.0:.2f]: training loss 1.094, val_loss: 0.128,  loss_classifier:0.00, loss_box_reg:0.01, loss_mask:0.04, loss_objectness:0.00, loss_rpn_box_reg:0.00,

# %%
# model.load_state_dict(torch.load('checkpoint.pth', weights_only=True))

# Our data are small but it seems we can continue training further since the graph below still shows
# that the model can still learn, i.e., underfit due to early training termination
fig, ax=plt.subplots(figsize=(4,4))
for name, losses in zip('train, validation'.split(','),[train_losses, val_losses]):
    losses=[l.detach().cpu() if isinstance(l, torch.Tensor) else l for l in losses]
    ax.plot(losses, label=name)
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
plt.legend(loc="upper right")

# %% [markdown]
# ### Inference
#
# Out test data is the same as validation data for this quick test on a small data, which is not how we should partition data typically

# %%
def alpha_bending(foreground, background, alpha):
    '''
    Args:
        foreground (Tensor): NxCxHxW image to be on the foreground
        background (Tensor): NxCxHxW image to be on the background
        alpha (float): opacity of the foreground
    '''
    background=background.to(torch.float32)
    foreground=foreground.to(torch.float32)
    C=max(background.shape[1], foreground.shape[1])
    output=torch.zeros(background.shape[0], C, *background.shape[-2:], dtype=background.dtype,
                       device=background.device)
    if foreground.shape[1]!=C: foreground=foreground.expand(foreground.shape[0],1,*foreground.shape[-2:])
    if background.shape[1]!=C: background=background.expand(background.shape[0],1,*background.shape[-2:])
    return background*(1.-alpha)+foreground*alpha

# %%
model.eval()
test_dataset=PennFudanDataset(root=os.path.join(main_dirpath, 'PennFudanPed'), image_dirname='PNGImages', mask_dirname='PedMasks',
                               annotation_dirname='Annotation', transforms=get_transform(is_train=False), indices=np.arange(160,170))

test_loader=torch.utils.data.DataLoader(val_dataset, batch_size=1,shuffle=False,collate_fn=utils.collate_fn)

# %%
all_input_images=[]
all_outputs=[]
for indx, (images, targets) in enumerate(test_loader):
    images=[im.to(device) for im in images]
    with torch.no_grad(): outputs=model(images)
    all_input_images.append(images)
    all_outputs.append(outputs)

# %%
import matplotlib.patches as patches

# visualize outputs

alpha=0.4
for i, (images,outputs) in enumerate(zip(all_input_images,all_outputs)):

    for image, output in zip(images, outputs):

        # turn heatmap to segmentation
        mask=(output['masks']>0.5).to(dtype=torch.uint8) # Nx1xHxW where N is the number of boxes
        # make binary mask RGB channel of cyan
        mask=torch.cat([torch.zeros_like(mask), mask, mask], dim=1) # NxCxHxW where C is RBG channels
        # convert CxHxW -> NxCxHxW
        background=image.unsqueeze(0).expand(output['masks'].shape[0], *image.shape)
        alpha_img=alpha_bending(foreground=mask, background=background, alpha=alpha)

        # boxes
        boxes=output['boxes'].cpu()
        x,y=boxes[:,0], boxes[:,1]
        size=boxes[:,2:]-boxes[:,:2]
        width, height=size[:,0], size[:,1]

        # scores
        scores=output['scores'].cpu()


        # visualize output
        fig, axes=plt.subplots(1, alpha_img.shape[0], figsize=(8,3))
        for i, al_im in enumerate(alpha_img):
            try: ax=axes[i]
            except: ax=axes
            ax.imshow(al_im.permute(1,2,0).cpu()) # CxHxW -> HxWxC
            rect = patches.Rectangle((x[i], y[i]), width[i], height[i], linewidth=2, edgecolor='c', facecolor='none')
            ax.add_patch(rect)
            ax.text(x[i]-1, y[i]-1, s=f'{scores[i]:.3f}', fontsize=8, fontweight='bold', color='c')
            ax.axis('off')
        plt.tight_layout(pad=0, w_pad=0, h_pad=0)
