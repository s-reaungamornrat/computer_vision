# %%
# %matplotlib inline

from typing import Optional, Union

import os
import sys
import wget
import time
import argparse

import torch
import torchvision
from torch import Tensor
import torch.nn.functional as F
from torchvision.ops import boxes as box_ops
from torchvision.ops.boxes import box_area
from torchvision.ops.roi_align import _bilinear_interpolate, roi_align
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

import numpy as np
import matplotlib.pyplot as plt

sys.path.append('../../../')
from computer_vision.mask_rcnn.dataset.penn_fudan_ped import PennFudanDataset, get_transform


torch.manual_seed(0)
np.random.seed(0)
torch.cuda.empty_cache()

# %%
# Create the parser
parser = argparse.ArgumentParser(description='MaskRCNN')

# Add arguments
parser.add_argument('--rpn-objectness-weight', type=float, default=10., help='weight to the loss of RPN objectness')
parser.add_argument('--rpn-box-regression-weight', type=float, default=50., help='weight to the loss of RPN box regression')
parser.add_argument('--roi-classifier-weight', type=float, default=1., help='weight to the loss of roi-head for object class')
parser.add_argument('--roi-box-regression-weight', type=float, default=5., help='weight to the loss for roi-head box regression')
parser.add_argument('--mask-weight', type=float, default=0.5, help='weight to mask loss')
parser.add_argument('--n-training', type=int, default=160, help='number of training data')
parser.add_argument('--max-epochs', type=int, default=160, help='maximum number of epochs')
parser.add_argument('--print-freq', type=int, default=5, help='how many batch before printing')

args = parser.parse_args('--max-epochs 1000  --print-freq 20'.split())
args
# Out:
# Namespace(rpn_objectness_weight=10.0, rpn_box_regression_weight=50.0, roi_classifier_weight=1.0, roi_box_regression_weight=5.0, mask_weight=0.5, n_training=160, max_epochs=1000, print_freq=20)

# %%
device=torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print('device ', device)

main_dirpath='D:/data/'
output_dirpath='D:/results/mask_rcnn'
if not os.path.isdir(output_dirpath): os.makedirs(output_dirpath)
# Out:
# device  cuda

# %%
main_url='https://raw.githubusercontent.com/pytorch/vision/main/references/detection'
for file in ['engine.py', 'utils.py','coco_utils.py','coco_eval.py', 'transforms.py']:
    if os.path.isfile(file): continue
    out=wget.download(url=f'{main_url}/{file}', out=None)
    print(file, out)

import utils

# %%
data_url='https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip'
if not os.path.isfile(os.path.join(main_dirpath, 'PennFudanPed.zip')): wget.download(url=data_url, out=main_dirpath)

# %%
num_classes=2
# load an instance segmentation model pre-trained on COCO
model=torchvision.models.detection.maskrcnn_resnet50_fpn_v2(weights='DEFAULT', rpn_pre_nms_top_n_train=800,
        rpn_pre_nms_top_n_test=500,  rpn_post_nms_top_n_train=800,  rpn_post_nms_top_n_test=500, box_detections_per_img=100,
        box_batch_size_per_image =400, rpn_batch_size_per_image=100)
# get number of input features for the classifier
in_features=model.roi_heads.box_predictor.cls_score.in_features
print('the number of inpute features for classifiers ', in_features)
# replace the pre-trained head with a new one
model.roi_heads.box_predictor=FastRCNNPredictor(in_features,  num_classes)

# get the number of input features for the mask classifiers
in_features_mask=model.roi_heads.mask_predictor.conv5_mask.in_channels
print('the number of input features for mask ', in_features_mask)
hidden_layer=256
# and replace the mask predictor with a new one
model.roi_heads.mask_predictor=MaskRCNNPredictor(in_features_mask, hidden_layer, num_classes)

# move model to the right device
model.to(device);

optimizer=torch.optim.AdamW(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
# Out:
# the number of inpute features for classifiers  1024
# the number of input features for mask  256

# %%
# there are 170 images
train_dataset=PennFudanDataset(root=os.path.join(main_dirpath, 'PennFudanPed'), image_dirname='PNGImages', mask_dirname='PedMasks',
                               annotation_dirname='Annotation', transforms=get_transform(is_train=True), indices=np.arange(160))
val_dataset=PennFudanDataset(root=os.path.join(main_dirpath, 'PennFudanPed'), image_dirname='PNGImages', mask_dirname='PedMasks',
                               annotation_dirname='Annotation', transforms=get_transform(is_train=False), indices=np.arange(160,170))
print('train_dataset ', len(train_dataset), ' val_dataset ', len(val_dataset))
# define training and validation data loaders
train_loader=torch.utils.data.DataLoader(train_dataset, batch_size=2,shuffle=True,collate_fn=utils.collate_fn)
val_loader=torch.utils.data.DataLoader(val_dataset, batch_size=2,shuffle=False,collate_fn=utils.collate_fn)
# Out:
# train_dataset  160  val_dataset  10

# %%
def train_epoch(model, train_loader, optimizer,weights, device, print_freq=1):
    """
    Returns:
        last_loss (float): average loss of this epoch
        it_time (float): elapse time per iteration
        epoch_time (float): elase time of this epoch in seconds
    """
    model.train()
    running_loss, running_runtime=0.,0.
    for i, (images, targets) in enumerate(train_loader, 1):
        start_it_time=time.time()
        # port data to device
        images=[im.to(device) for im in images]
        targets=[{k:v.to(device) if isinstance(v, torch.Tensor) else v for k, v in target.items()} for target in targets]

        # zero gradients
        optimizer.zero_grad()

        # estimate
        outputs=model(images, targets)

        # compute loss
        loss, log=0., ''
        for name, loss_term in outputs.items():
            loss+=weights[name]*loss_term
            log+=f' {name}:{loss.item():.3f},'
        loss.backward()

        # adjusting parameters
        optimizer.step()

        # gather data and report
        running_loss+=loss.item()
        running_runtime+=(time.time()-start_it_time)
        if print_freq>0 and i%print_freq==0:
            print(f'\tIteration {i} [{100*i/len(train_loader):.2f}%] took {time.time()-start_it_time:.3f} s: total:{loss.item():.3f}, {log}', flush=True)
    last_loss=running_loss/len(train_loader)
    it_time=running_runtime/len(train_loader)
    return last_loss, it_time, 

def validation(model, val_loader, weights, device):
    #model.eval()
    running_loss, loss_per_task=0., dict()
    for i, (images, targets) in enumerate(val_loader, 1):

        # port data to device
        images=[im.to(device) for im in images]
        targets=[{k:v.to(device) if isinstance(v, torch.Tensor) else v for k, v in target.items()} for target in targets]

        with torch.no_grad(): outputs=model(images, targets)
        # compute loss
        loss=0
        for name, loss_term in outputs.items():
            loss+=weights[name]*loss_term
            if name not in loss_per_task: loss_per_task[name]=0.
            loss_per_task[name]+=loss_term.item()
        running_loss+=loss.item()
        
    running_loss/=len(val_loader)
    loss_per_task={k:n/len(val_loader) for k, n in loss_per_task.items()}
    return loss, loss_per_task

# %%
weights={'loss_classifier':args.roi_classifier_weight, 'loss_box_reg':args.roi_box_regression_weight,
         'loss_mask':args.mask_weight,'loss_objectness':args.rpn_objectness_weight,
         'loss_rpn_box_reg':args.rpn_box_regression_weight}

best_vloss=np.inf
train_losses, val_losses=[],[]
for epoch in range(1, args.max_epochs+1):
    start_time=time.time()
    # make sure gradient tracking is on
    t_loss, it_time=train_epoch(model, train_loader, optimizer, weights=weights, device=device, print_freq=args.print_freq)

    # validation
    v_loss, v_loss_per_task=validation(model, val_loader, weights=weights, device=device)

    # record training measures
    train_losses+=[t_loss]
    val_losses+=[v_loss]

    # print progress
    log=''
    for k, v in v_loss_per_task.items(): log+=f' {k}:{v:.2f},'
    print(f'Epoch {epoch} [{(100.*epoch/args.max_epochs):.2f}] took {time.time()-start_time:.2f} s: training loss {t_loss:.3f}, val_loss: {v_loss:.3f}, {log}, each iteration took {it_time:.2f} s', flush=True)

    if v_loss<best_vloss and epoch>1:
        best_vloss=v_loss
        torch.save(model.state_dict(), os.path.join(output_dirpath, 'best_checkpoint.pth'))

    torch.save(model.state_dict(), os.path.join(output_dirpath,'checkpoint.pth'))
# Out:
# 	Iteration 20 [25.00%] took 0.270 s: total:2.529,  loss_classifier:0.069, loss_box_reg:0.710, loss_mask:0.903, loss_objectness:1.665, loss_rpn_box_reg:2.529,
# 	Iteration 40 [50.00%] took 0.273 s: total:4.614,  loss_classifier:0.250, loss_box_reg:1.574, loss_mask:1.801, loss_objectness:2.005, loss_rpn_box_reg:4.614,
# 	Iteration 60 [75.00%] took 0.219 s: total:2.792,  loss_classifier:0.092, loss_box_reg:0.683, loss_mask:0.864, loss_objectness:1.304, loss_rpn_box_reg:2.792,
# 	Iteration 80 [100.00%] took 0.266 s: total:2.824,  loss_classifier:0.140, loss_box_reg:0.940, loss_mask:1.105, loss_objectness:1.330, loss_rpn_box_reg:2.824,
# Epoch 1 [0.1:.2f] took 23.53 s: training loss 3.793, val_loss: 2.640,  loss_classifier:0.11, loss_box_reg:0.14, loss_mask:0.46, loss_objectness:0.02, loss_rpn_box_reg:0.02,, each iteration took 0.26 s
# 	Iteration 20 [25.00%] took 0.238 s: total:3.017,  loss_classifier:0.179, loss_box_reg:1.330, loss_mask:1.507, loss_objectness:1.636, loss_rpn_box_reg:3.017,
# 	Iteration 40 [50.00%] took 0.242 s: total:6.090,  loss_classifier:0.148, loss_box_reg:0.988, loss_mask:1.163, loss_objectness:2.483, loss_rpn_box_reg:6.090,
# 	Iteration 60 [75.00%] took 0.207 s: total:2.539,  loss_classifier:0.124, loss_box_reg:1.151, loss_mask:1.435, loss_objectness:1.563, loss_rpn_box_reg:2.539,
# 	Iteration 80 [100.00%] took 0.275 s: total:2.812,  loss_classifier:0.127, loss_box_reg:0.883, loss_mask:1.099, loss_objectness:1.457, loss_rpn_box_reg:2.812,
# Epoch 2 [0.2:.2f] took 22.15 s: training loss 3.364, val_loss: 2.078,  loss_classifier:0.10, loss_box_reg:0.12, loss_mask:0.47, loss_objectness:0.01, loss_rpn_box_reg:0.02,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.224 s: total:2.341,  loss_classifier:0.053, loss_box_reg:0.593, loss_mask:0.755, loss_objectness:1.038, loss_rpn_box_reg:2.341,
# 	Iteration 40 [50.00%] took 0.248 s: total:3.820,  loss_classifier:0.126, loss_box_reg:1.027, loss_mask:1.190, loss_objectness:1.263, loss_rpn_box_reg:3.820,
# 	Iteration 60 [75.00%] took 0.211 s: total:2.868,  loss_classifier:0.110, loss_box_reg:0.882, loss_mask:1.066, loss_objectness:1.321, loss_rpn_box_reg:2.868,
# 	Iteration 80 [100.00%] took 0.235 s: total:1.114,  loss_classifier:0.079, loss_box_reg:0.517, loss_mask:0.724, loss_objectness:0.768, loss_rpn_box_reg:1.114,
# Epoch 3 [0.3:.2f] took 22.51 s: training loss 3.176, val_loss: 1.632,  loss_classifier:0.09, loss_box_reg:0.13, loss_mask:0.33, loss_objectness:0.01, loss_rpn_box_reg:0.02,, each iteration took 0.25 s
# 	Iteration 20 [25.00%] took 0.233 s: total:2.360,  loss_classifier:0.080, loss_box_reg:0.570, loss_mask:0.703, loss_objectness:1.106, loss_rpn_box_reg:2.360,
# 	Iteration 40 [50.00%] took 0.276 s: total:4.547,  loss_classifier:0.112, loss_box_reg:1.131, loss_mask:1.297, loss_objectness:1.578, loss_rpn_box_reg:4.547,
# 	Iteration 60 [75.00%] took 0.240 s: total:3.300,  loss_classifier:0.088, loss_box_reg:0.475, loss_mask:0.614, loss_objectness:0.677, loss_rpn_box_reg:3.300,
# 	Iteration 80 [100.00%] took 0.224 s: total:1.637,  loss_classifier:0.093, loss_box_reg:0.396, loss_mask:0.533, loss_objectness:0.728, loss_rpn_box_reg:1.637,
# Epoch 4 [0.4:.2f] took 22.15 s: training loss 2.828, val_loss: 1.603,  loss_classifier:0.11, loss_box_reg:0.11, loss_mask:0.34, loss_objectness:0.02, loss_rpn_box_reg:0.02,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.272 s: total:3.528,  loss_classifier:0.121, loss_box_reg:1.164, loss_mask:1.367, loss_objectness:1.529, loss_rpn_box_reg:3.528,
# 	Iteration 40 [50.00%] took 0.212 s: total:2.202,  loss_classifier:0.097, loss_box_reg:0.548, loss_mask:0.649, loss_objectness:0.660, loss_rpn_box_reg:2.202,
# 	Iteration 60 [75.00%] took 0.232 s: total:4.929,  loss_classifier:0.112, loss_box_reg:0.709, loss_mask:0.833, loss_objectness:2.021, loss_rpn_box_reg:4.929,
# 	Iteration 80 [100.00%] took 0.265 s: total:3.224,  loss_classifier:0.079, loss_box_reg:0.715, loss_mask:0.918, loss_objectness:1.207, loss_rpn_box_reg:3.224,
# Epoch 5 [0.5:.2f] took 22.16 s: training loss 2.793, val_loss: 1.157,  loss_classifier:0.07, loss_box_reg:0.09, loss_mask:0.33, loss_objectness:0.01, loss_rpn_box_reg:0.02,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.239 s: total:1.901,  loss_classifier:0.107, loss_box_reg:0.604, loss_mask:0.738, loss_objectness:0.900, loss_rpn_box_reg:1.901,
# 	Iteration 40 [50.00%] took 0.283 s: total:5.255,  loss_classifier:0.146, loss_box_reg:1.711, loss_mask:1.951, loss_objectness:2.370, loss_rpn_box_reg:5.255,
# 	Iteration 60 [75.00%] took 0.207 s: total:2.231,  loss_classifier:0.087, loss_box_reg:0.834, loss_mask:1.026, loss_objectness:1.107, loss_rpn_box_reg:2.231,
# 	Iteration 80 [100.00%] took 0.206 s: total:1.944,  loss_classifier:0.085, loss_box_reg:0.548, loss_mask:0.732, loss_objectness:1.179, loss_rpn_box_reg:1.944,
# Epoch 6 [0.6:.2f] took 21.94 s: training loss 2.848, val_loss: 1.814,  loss_classifier:0.09, loss_box_reg:0.12, loss_mask:0.36, loss_objectness:0.03, loss_rpn_box_reg:0.02,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.237 s: total:3.069,  loss_classifier:0.143, loss_box_reg:1.084, loss_mask:1.258, loss_objectness:1.602, loss_rpn_box_reg:3.069,
# 	Iteration 40 [50.00%] took 0.229 s: total:8.056,  loss_classifier:0.391, loss_box_reg:1.934, loss_mask:2.123, loss_objectness:4.661, loss_rpn_box_reg:8.056,
# 	Iteration 60 [75.00%] took 0.214 s: total:1.940,  loss_classifier:0.055, loss_box_reg:0.572, loss_mask:0.681, loss_objectness:0.800, loss_rpn_box_reg:1.940,
# 	Iteration 80 [100.00%] took 0.252 s: total:2.085,  loss_classifier:0.134, loss_box_reg:0.891, loss_mask:1.026, loss_objectness:1.050, loss_rpn_box_reg:2.085,
# Epoch 7 [0.7:.2f] took 21.87 s: training loss 2.716, val_loss: 1.147,  loss_classifier:0.08, loss_box_reg:0.09, loss_mask:0.27, loss_objectness:0.01, loss_rpn_box_reg:0.02,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.207 s: total:1.774,  loss_classifier:0.131, loss_box_reg:1.140, loss_mask:1.293, loss_objectness:1.321, loss_rpn_box_reg:1.774,
# 	Iteration 40 [50.00%] took 0.235 s: total:3.513,  loss_classifier:0.121, loss_box_reg:0.803, loss_mask:0.940, loss_objectness:1.179, loss_rpn_box_reg:3.513,
# 	Iteration 60 [75.00%] took 0.206 s: total:1.159,  loss_classifier:0.040, loss_box_reg:0.348, loss_mask:0.500, loss_objectness:0.584, loss_rpn_box_reg:1.159,
# 	Iteration 80 [100.00%] took 0.301 s: total:4.209,  loss_classifier:0.194, loss_box_reg:1.262, loss_mask:1.397, loss_objectness:1.638, loss_rpn_box_reg:4.209,
# Epoch 8 [0.8:.2f] took 21.91 s: training loss 2.904, val_loss: 2.281,  loss_classifier:0.07, loss_box_reg:0.10, loss_mask:0.31, loss_objectness:0.03, loss_rpn_box_reg:0.01,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.266 s: total:3.579,  loss_classifier:0.160, loss_box_reg:1.301, loss_mask:1.509, loss_objectness:1.598, loss_rpn_box_reg:3.579,
# 	Iteration 40 [50.00%] took 0.245 s: total:4.446,  loss_classifier:0.075, loss_box_reg:0.836, loss_mask:0.995, loss_objectness:1.201, loss_rpn_box_reg:4.446,
# 	Iteration 60 [75.00%] took 0.269 s: total:3.188,  loss_classifier:0.131, loss_box_reg:1.068, loss_mask:1.274, loss_objectness:1.757, loss_rpn_box_reg:3.188,
# 	Iteration 80 [100.00%] took 0.271 s: total:1.012,  loss_classifier:0.062, loss_box_reg:0.282, loss_mask:0.382, loss_objectness:0.400, loss_rpn_box_reg:1.012,
# Epoch 9 [0.9:.2f] took 21.97 s: training loss 2.693, val_loss: 1.800,  loss_classifier:0.07, loss_box_reg:0.08, loss_mask:0.30, loss_objectness:0.01, loss_rpn_box_reg:0.02,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.212 s: total:1.966,  loss_classifier:0.080, loss_box_reg:0.505, loss_mask:0.684, loss_objectness:0.886, loss_rpn_box_reg:1.966,
# 	Iteration 40 [50.00%] took 0.245 s: total:4.508,  loss_classifier:0.185, loss_box_reg:1.694, loss_mask:1.888, loss_objectness:2.021, loss_rpn_box_reg:4.508,
# 	Iteration 60 [75.00%] took 0.233 s: total:2.079,  loss_classifier:0.115, loss_box_reg:0.653, loss_mask:0.782, loss_objectness:0.839, loss_rpn_box_reg:2.079,
# 	Iteration 80 [100.00%] took 0.231 s: total:3.920,  loss_classifier:0.064, loss_box_reg:0.502, loss_mask:0.626, loss_objectness:1.094, loss_rpn_box_reg:3.920,
# Epoch 10 [1.0:.2f] took 21.70 s: training loss 2.602, val_loss: 1.421,  loss_classifier:0.08, loss_box_reg:0.09, loss_mask:0.28, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.249 s: total:1.685,  loss_classifier:0.105, loss_box_reg:0.746, loss_mask:0.883, loss_objectness:0.967, loss_rpn_box_reg:1.685,
# 	Iteration 40 [50.00%] took 0.214 s: total:2.115,  loss_classifier:0.107, loss_box_reg:0.783, loss_mask:0.897, loss_objectness:0.940, loss_rpn_box_reg:2.115,
# 	Iteration 60 [75.00%] took 0.267 s: total:4.355,  loss_classifier:0.176, loss_box_reg:1.190, loss_mask:1.394, loss_objectness:1.598, loss_rpn_box_reg:4.355,
# 	Iteration 80 [100.00%] took 0.206 s: total:0.859,  loss_classifier:0.048, loss_box_reg:0.279, loss_mask:0.409, loss_objectness:0.626, loss_rpn_box_reg:0.859,
# Epoch 11 [1.1:.2f] took 21.74 s: training loss 2.457, val_loss: 1.021,  loss_classifier:0.06, loss_box_reg:0.07, loss_mask:0.26, loss_objectness:0.01, loss_rpn_box_reg:0.02,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.280 s: total:4.038,  loss_classifier:0.159, loss_box_reg:0.943, loss_mask:1.084, loss_objectness:1.152, loss_rpn_box_reg:4.038,
# 	Iteration 40 [50.00%] took 0.196 s: total:1.078,  loss_classifier:0.071, loss_box_reg:0.546, loss_mask:0.647, loss_objectness:0.680, loss_rpn_box_reg:1.078,
# 	Iteration 60 [75.00%] took 0.225 s: total:1.852,  loss_classifier:0.075, loss_box_reg:0.503, loss_mask:0.625, loss_objectness:0.775, loss_rpn_box_reg:1.852,
# 	Iteration 80 [100.00%] took 0.229 s: total:2.446,  loss_classifier:0.087, loss_box_reg:0.780, loss_mask:0.923, loss_objectness:1.080, loss_rpn_box_reg:2.446,
# Epoch 12 [1.2:.2f] took 21.96 s: training loss 2.320, val_loss: 1.448,  loss_classifier:0.05, loss_box_reg:0.08, loss_mask:0.28, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.230 s: total:2.492,  loss_classifier:0.076, loss_box_reg:0.718, loss_mask:0.872, loss_objectness:1.200, loss_rpn_box_reg:2.492,
# 	Iteration 40 [50.00%] took 0.291 s: total:5.497,  loss_classifier:0.171, loss_box_reg:1.968, loss_mask:2.112, loss_objectness:2.204, loss_rpn_box_reg:5.497,
# 	Iteration 60 [75.00%] took 0.269 s: total:2.860,  loss_classifier:0.120, loss_box_reg:0.687, loss_mask:0.823, loss_objectness:1.557, loss_rpn_box_reg:2.860,
# 	Iteration 80 [100.00%] took 0.256 s: total:2.076,  loss_classifier:0.061, loss_box_reg:0.699, loss_mask:0.814, loss_objectness:0.854, loss_rpn_box_reg:2.076,
# Epoch 13 [1.3:.2f] took 22.09 s: training loss 2.262, val_loss: 1.056,  loss_classifier:0.06, loss_box_reg:0.08, loss_mask:0.24, loss_objectness:0.00, loss_rpn_box_reg:0.02,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.243 s: total:2.901,  loss_classifier:0.092, loss_box_reg:1.027, loss_mask:1.132, loss_objectness:1.341, loss_rpn_box_reg:2.901,
# 	Iteration 40 [50.00%] took 0.211 s: total:1.364,  loss_classifier:0.049, loss_box_reg:0.367, loss_mask:0.469, loss_objectness:0.588, loss_rpn_box_reg:1.364,
# 	Iteration 60 [75.00%] took 0.243 s: total:2.156,  loss_classifier:0.079, loss_box_reg:0.658, loss_mask:0.785, loss_objectness:0.848, loss_rpn_box_reg:2.156,
# 	Iteration 80 [100.00%] took 0.205 s: total:2.035,  loss_classifier:0.132, loss_box_reg:0.953, loss_mask:1.221, loss_objectness:1.275, loss_rpn_box_reg:2.035,
# Epoch 14 [1.4:.2f] took 22.13 s: training loss 2.930, val_loss: 2.173,  loss_classifier:0.11, loss_box_reg:0.11, loss_mask:0.49, loss_objectness:0.04, loss_rpn_box_reg:0.01,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.218 s: total:1.634,  loss_classifier:0.081, loss_box_reg:0.693, loss_mask:0.883, loss_objectness:1.066, loss_rpn_box_reg:1.634,
# 	Iteration 40 [50.00%] took 0.272 s: total:3.223,  loss_classifier:0.142, loss_box_reg:1.147, loss_mask:1.308, loss_objectness:1.362, loss_rpn_box_reg:3.223,
# 	Iteration 60 [75.00%] took 0.255 s: total:0.969,  loss_classifier:0.086, loss_box_reg:0.433, loss_mask:0.576, loss_objectness:0.693, loss_rpn_box_reg:0.969,
# 	Iteration 80 [100.00%] took 0.267 s: total:6.052,  loss_classifier:0.116, loss_box_reg:0.811, loss_mask:0.950, loss_objectness:3.011, loss_rpn_box_reg:6.052,
# Epoch 15 [1.5:.2f] took 21.90 s: training loss 3.008, val_loss: 1.552,  loss_classifier:0.08, loss_box_reg:0.09, loss_mask:0.33, loss_objectness:0.01, loss_rpn_box_reg:0.02,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.198 s: total:1.754,  loss_classifier:0.092, loss_box_reg:0.892, loss_mask:1.108, loss_objectness:1.129, loss_rpn_box_reg:1.754,
# 	Iteration 40 [50.00%] took 0.236 s: total:1.490,  loss_classifier:0.052, loss_box_reg:0.250, loss_mask:0.374, loss_objectness:0.425, loss_rpn_box_reg:1.490,
# 	Iteration 60 [75.00%] took 0.223 s: total:2.612,  loss_classifier:0.067, loss_box_reg:0.786, loss_mask:0.921, loss_objectness:1.011, loss_rpn_box_reg:2.612,
# 	Iteration 80 [100.00%] took 0.198 s: total:2.211,  loss_classifier:0.084, loss_box_reg:0.430, loss_mask:0.607, loss_objectness:0.888, loss_rpn_box_reg:2.211,
# Epoch 16 [1.6:.2f] took 20.52 s: training loss 2.504, val_loss: 1.416,  loss_classifier:0.09, loss_box_reg:0.11, loss_mask:0.28, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.206 s: total:1.516,  loss_classifier:0.061, loss_box_reg:0.470, loss_mask:0.568, loss_objectness:0.638, loss_rpn_box_reg:1.516,
# 	Iteration 40 [50.00%] took 0.218 s: total:1.190,  loss_classifier:0.043, loss_box_reg:0.333, loss_mask:0.423, loss_objectness:0.444, loss_rpn_box_reg:1.190,
# 	Iteration 60 [75.00%] took 0.272 s: total:2.463,  loss_classifier:0.057, loss_box_reg:0.550, loss_mask:0.648, loss_objectness:1.145, loss_rpn_box_reg:2.463,
# 	Iteration 80 [100.00%] took 0.217 s: total:1.868,  loss_classifier:0.062, loss_box_reg:0.600, loss_mask:0.714, loss_objectness:0.881, loss_rpn_box_reg:1.868,
# Epoch 17 [1.7:.2f] took 21.58 s: training loss 2.302, val_loss: 1.247,  loss_classifier:0.07, loss_box_reg:0.10, loss_mask:0.28, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.210 s: total:1.358,  loss_classifier:0.066, loss_box_reg:0.292, loss_mask:0.413, loss_objectness:0.466, loss_rpn_box_reg:1.358,
# 	Iteration 40 [50.00%] took 0.260 s: total:4.068,  loss_classifier:0.081, loss_box_reg:0.868, loss_mask:0.995, loss_objectness:1.254, loss_rpn_box_reg:4.068,
# 	Iteration 60 [75.00%] took 0.187 s: total:1.571,  loss_classifier:0.034, loss_box_reg:0.234, loss_mask:0.333, loss_objectness:0.599, loss_rpn_box_reg:1.571,
# 	Iteration 80 [100.00%] took 0.225 s: total:1.559,  loss_classifier:0.066, loss_box_reg:0.499, loss_mask:0.606, loss_objectness:1.010, loss_rpn_box_reg:1.559,
# Epoch 18 [1.8:.2f] took 21.25 s: training loss 2.245, val_loss: 1.108,  loss_classifier:0.06, loss_box_reg:0.08, loss_mask:0.25, loss_objectness:0.00, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.258 s: total:3.808,  loss_classifier:0.082, loss_box_reg:0.489, loss_mask:0.591, loss_objectness:0.745, loss_rpn_box_reg:3.808,
# 	Iteration 40 [50.00%] took 0.232 s: total:2.007,  loss_classifier:0.093, loss_box_reg:0.772, loss_mask:0.871, loss_objectness:0.921, loss_rpn_box_reg:2.007,
# 	Iteration 60 [75.00%] took 0.221 s: total:3.607,  loss_classifier:0.069, loss_box_reg:0.646, loss_mask:0.747, loss_objectness:1.140, loss_rpn_box_reg:3.607,
# 	Iteration 80 [100.00%] took 0.202 s: total:0.892,  loss_classifier:0.040, loss_box_reg:0.384, loss_mask:0.467, loss_objectness:0.609, loss_rpn_box_reg:0.892,
# Epoch 19 [1.9:.2f] took 20.25 s: training loss 2.158, val_loss: 1.064,  loss_classifier:0.06, loss_box_reg:0.08, loss_mask:0.24, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.235 s: total:4.449,  loss_classifier:0.108, loss_box_reg:0.776, loss_mask:0.973, loss_objectness:1.133, loss_rpn_box_reg:4.449,
# 	Iteration 40 [50.00%] took 0.232 s: total:1.183,  loss_classifier:0.057, loss_box_reg:0.418, loss_mask:0.528, loss_objectness:0.534, loss_rpn_box_reg:1.183,
# 	Iteration 60 [75.00%] took 0.257 s: total:4.385,  loss_classifier:0.103, loss_box_reg:0.826, loss_mask:0.962, loss_objectness:1.002, loss_rpn_box_reg:4.385,
# 	Iteration 80 [100.00%] took 0.244 s: total:3.138,  loss_classifier:0.073, loss_box_reg:0.761, loss_mask:0.874, loss_objectness:0.959, loss_rpn_box_reg:3.138,
# Epoch 20 [2.0:.2f] took 20.12 s: training loss 2.034, val_loss: 0.929,  loss_classifier:0.06, loss_box_reg:0.08, loss_mask:0.24, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.225 s: total:0.981,  loss_classifier:0.050, loss_box_reg:0.218, loss_mask:0.331, loss_objectness:0.440, loss_rpn_box_reg:0.981,
# 	Iteration 40 [50.00%] took 0.275 s: total:2.189,  loss_classifier:0.068, loss_box_reg:0.562, loss_mask:0.661, loss_objectness:0.673, loss_rpn_box_reg:2.189,
# 	Iteration 60 [75.00%] took 0.214 s: total:0.708,  loss_classifier:0.062, loss_box_reg:0.379, loss_mask:0.483, loss_objectness:0.533, loss_rpn_box_reg:0.708,
# 	Iteration 80 [100.00%] took 0.216 s: total:2.183,  loss_classifier:0.071, loss_box_reg:0.511, loss_mask:0.636, loss_objectness:0.749, loss_rpn_box_reg:2.183,
# Epoch 21 [2.1:.2f] took 20.27 s: training loss 2.074, val_loss: 1.022,  loss_classifier:0.07, loss_box_reg:0.09, loss_mask:0.26, loss_objectness:0.01, loss_rpn_box_reg:0.02,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.213 s: total:2.495,  loss_classifier:0.051, loss_box_reg:0.470, loss_mask:0.566, loss_objectness:0.576, loss_rpn_box_reg:2.495,
# 	Iteration 40 [50.00%] took 0.253 s: total:2.255,  loss_classifier:0.106, loss_box_reg:0.703, loss_mask:0.865, loss_objectness:0.975, loss_rpn_box_reg:2.255,
# 	Iteration 60 [75.00%] took 0.207 s: total:1.323,  loss_classifier:0.077, loss_box_reg:0.520, loss_mask:0.647, loss_objectness:0.653, loss_rpn_box_reg:1.323,
# 	Iteration 80 [100.00%] took 0.225 s: total:2.442,  loss_classifier:0.135, loss_box_reg:1.055, loss_mask:1.213, loss_objectness:1.222, loss_rpn_box_reg:2.442,
# Epoch 22 [2.2:.2f] took 20.23 s: training loss 2.167, val_loss: 1.110,  loss_classifier:0.06, loss_box_reg:0.08, loss_mask:0.24, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.233 s: total:1.991,  loss_classifier:0.087, loss_box_reg:0.766, loss_mask:0.885, loss_objectness:0.926, loss_rpn_box_reg:1.991,
# 	Iteration 40 [50.00%] took 0.188 s: total:1.244,  loss_classifier:0.051, loss_box_reg:0.512, loss_mask:0.687, loss_objectness:0.818, loss_rpn_box_reg:1.244,
# 	Iteration 60 [75.00%] took 0.259 s: total:3.617,  loss_classifier:0.073, loss_box_reg:0.825, loss_mask:0.973, loss_objectness:0.996, loss_rpn_box_reg:3.617,
# 	Iteration 80 [100.00%] took 0.258 s: total:5.603,  loss_classifier:0.046, loss_box_reg:0.558, loss_mask:0.668, loss_objectness:0.921, loss_rpn_box_reg:5.603,
# Epoch 23 [2.3:.2f] took 20.34 s: training loss 2.140, val_loss: 0.936,  loss_classifier:0.06, loss_box_reg:0.06, loss_mask:0.23, loss_objectness:0.01, loss_rpn_box_reg:0.02,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.294 s: total:2.671,  loss_classifier:0.072, loss_box_reg:0.680, loss_mask:0.817, loss_objectness:1.166, loss_rpn_box_reg:2.671,
# 	Iteration 40 [50.00%] took 0.240 s: total:0.890,  loss_classifier:0.047, loss_box_reg:0.381, loss_mask:0.484, loss_objectness:0.499, loss_rpn_box_reg:0.890,
# 	Iteration 60 [75.00%] took 0.215 s: total:1.500,  loss_classifier:0.075, loss_box_reg:0.655, loss_mask:0.853, loss_objectness:0.886, loss_rpn_box_reg:1.500,
# 	Iteration 80 [100.00%] took 0.199 s: total:2.310,  loss_classifier:0.118, loss_box_reg:0.925, loss_mask:1.118, loss_objectness:1.164, loss_rpn_box_reg:2.310,
# Epoch 24 [2.4:.2f] took 20.57 s: training loss 1.983, val_loss: 1.109,  loss_classifier:0.05, loss_box_reg:0.07, loss_mask:0.21, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.236 s: total:2.116,  loss_classifier:0.052, loss_box_reg:0.483, loss_mask:0.590, loss_objectness:0.994, loss_rpn_box_reg:2.116,
# 	Iteration 40 [50.00%] took 0.223 s: total:1.991,  loss_classifier:0.101, loss_box_reg:0.827, loss_mask:0.949, loss_objectness:0.966, loss_rpn_box_reg:1.991,
# 	Iteration 60 [75.00%] took 0.283 s: total:2.160,  loss_classifier:0.065, loss_box_reg:0.531, loss_mask:0.664, loss_objectness:0.709, loss_rpn_box_reg:2.160,
# 	Iteration 80 [100.00%] took 0.196 s: total:1.700,  loss_classifier:0.051, loss_box_reg:0.597, loss_mask:0.786, loss_objectness:0.799, loss_rpn_box_reg:1.700,
# Epoch 25 [2.5:.2f] took 20.21 s: training loss 1.914, val_loss: 1.027,  loss_classifier:0.06, loss_box_reg:0.08, loss_mask:0.22, loss_objectness:0.00, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.192 s: total:0.752,  loss_classifier:0.056, loss_box_reg:0.409, loss_mask:0.492, loss_objectness:0.512, loss_rpn_box_reg:0.752,
# 	Iteration 40 [50.00%] took 0.235 s: total:2.643,  loss_classifier:0.094, loss_box_reg:0.656, loss_mask:0.775, loss_objectness:0.970, loss_rpn_box_reg:2.643,
# 	Iteration 60 [75.00%] took 0.244 s: total:0.514,  loss_classifier:0.042, loss_box_reg:0.221, loss_mask:0.346, loss_objectness:0.387, loss_rpn_box_reg:0.514,
# 	Iteration 80 [100.00%] took 0.217 s: total:2.243,  loss_classifier:0.153, loss_box_reg:0.930, loss_mask:1.118, loss_objectness:1.262, loss_rpn_box_reg:2.243,
# Epoch 26 [2.6:.2f] took 20.68 s: training loss 1.999, val_loss: 1.334,  loss_classifier:0.07, loss_box_reg:0.09, loss_mask:0.30, loss_objectness:0.02, loss_rpn_box_reg:0.02,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.255 s: total:4.460,  loss_classifier:0.192, loss_box_reg:1.567, loss_mask:1.737, loss_objectness:1.836, loss_rpn_box_reg:4.460,
# 	Iteration 40 [50.00%] took 0.257 s: total:1.780,  loss_classifier:0.061, loss_box_reg:0.667, loss_mask:0.772, loss_objectness:0.793, loss_rpn_box_reg:1.780,
# 	Iteration 60 [75.00%] took 0.211 s: total:1.401,  loss_classifier:0.073, loss_box_reg:0.510, loss_mask:0.645, loss_objectness:0.650, loss_rpn_box_reg:1.401,
# 	Iteration 80 [100.00%] took 0.186 s: total:1.419,  loss_classifier:0.040, loss_box_reg:0.407, loss_mask:0.518, loss_objectness:0.865, loss_rpn_box_reg:1.419,
# Epoch 27 [2.7:.2f] took 21.04 s: training loss 2.116, val_loss: 1.010,  loss_classifier:0.05, loss_box_reg:0.06, loss_mask:0.25, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.216 s: total:1.014,  loss_classifier:0.036, loss_box_reg:0.303, loss_mask:0.381, loss_objectness:0.482, loss_rpn_box_reg:1.014,
# 	Iteration 40 [50.00%] took 0.262 s: total:2.594,  loss_classifier:0.073, loss_box_reg:0.960, loss_mask:1.089, loss_objectness:1.117, loss_rpn_box_reg:2.594,
# 	Iteration 60 [75.00%] took 0.190 s: total:1.312,  loss_classifier:0.040, loss_box_reg:0.417, loss_mask:0.555, loss_objectness:0.595, loss_rpn_box_reg:1.312,
# 	Iteration 80 [100.00%] took 0.221 s: total:1.408,  loss_classifier:0.031, loss_box_reg:0.318, loss_mask:0.419, loss_objectness:0.429, loss_rpn_box_reg:1.408,
# Epoch 28 [2.8:.2f] took 20.16 s: training loss 1.944, val_loss: 0.809,  loss_classifier:0.04, loss_box_reg:0.06, loss_mask:0.24, loss_objectness:0.01, loss_rpn_box_reg:0.02,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.213 s: total:0.940,  loss_classifier:0.041, loss_box_reg:0.406, loss_mask:0.495, loss_objectness:0.514, loss_rpn_box_reg:0.940,
# 	Iteration 40 [50.00%] took 0.275 s: total:1.274,  loss_classifier:0.072, loss_box_reg:0.584, loss_mask:0.670, loss_objectness:0.678, loss_rpn_box_reg:1.274,
# 	Iteration 60 [75.00%] took 0.195 s: total:1.445,  loss_classifier:0.046, loss_box_reg:0.624, loss_mask:0.775, loss_objectness:0.910, loss_rpn_box_reg:1.445,
# 	Iteration 80 [100.00%] took 0.192 s: total:1.014,  loss_classifier:0.039, loss_box_reg:0.342, loss_mask:0.424, loss_objectness:0.485, loss_rpn_box_reg:1.014,
# Epoch 29 [2.9:.2f] took 20.39 s: training loss 1.926, val_loss: 1.026,  loss_classifier:0.06, loss_box_reg:0.08, loss_mask:0.23, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.237 s: total:3.653,  loss_classifier:0.090, loss_box_reg:0.582, loss_mask:0.690, loss_objectness:0.780, loss_rpn_box_reg:3.653,
# 	Iteration 40 [50.00%] took 0.232 s: total:0.739,  loss_classifier:0.064, loss_box_reg:0.321, loss_mask:0.431, loss_objectness:0.475, loss_rpn_box_reg:0.739,
# 	Iteration 60 [75.00%] took 0.194 s: total:1.892,  loss_classifier:0.067, loss_box_reg:0.619, loss_mask:0.807, loss_objectness:0.869, loss_rpn_box_reg:1.892,
# 	Iteration 80 [100.00%] took 0.189 s: total:1.167,  loss_classifier:0.043, loss_box_reg:0.434, loss_mask:0.539, loss_objectness:0.622, loss_rpn_box_reg:1.167,
# Epoch 30 [3.0:.2f] took 20.39 s: training loss 1.744, val_loss: 0.910,  loss_classifier:0.05, loss_box_reg:0.06, loss_mask:0.22, loss_objectness:0.01, loss_rpn_box_reg:0.02,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.208 s: total:1.638,  loss_classifier:0.119, loss_box_reg:0.714, loss_mask:0.851, loss_objectness:1.034, loss_rpn_box_reg:1.638,
# 	Iteration 40 [50.00%] took 0.235 s: total:1.552,  loss_classifier:0.041, loss_box_reg:0.388, loss_mask:0.473, loss_objectness:0.661, loss_rpn_box_reg:1.552,
# 	Iteration 60 [75.00%] took 0.217 s: total:1.647,  loss_classifier:0.061, loss_box_reg:0.482, loss_mask:0.574, loss_objectness:0.648, loss_rpn_box_reg:1.647,
# 	Iteration 80 [100.00%] took 0.252 s: total:1.932,  loss_classifier:0.069, loss_box_reg:0.705, loss_mask:0.795, loss_objectness:0.801, loss_rpn_box_reg:1.932,
# Epoch 31 [3.1:.2f] took 20.22 s: training loss 1.698, val_loss: 0.958,  loss_classifier:0.05, loss_box_reg:0.08, loss_mask:0.21, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.178 s: total:0.660,  loss_classifier:0.045, loss_box_reg:0.290, loss_mask:0.389, loss_objectness:0.467, loss_rpn_box_reg:0.660,
# 	Iteration 40 [50.00%] took 0.259 s: total:2.234,  loss_classifier:0.063, loss_box_reg:0.626, loss_mask:0.719, loss_objectness:0.826, loss_rpn_box_reg:2.234,
# 	Iteration 60 [75.00%] took 0.184 s: total:1.745,  loss_classifier:0.049, loss_box_reg:0.298, loss_mask:0.392, loss_objectness:0.412, loss_rpn_box_reg:1.745,
# 	Iteration 80 [100.00%] took 0.245 s: total:0.966,  loss_classifier:0.035, loss_box_reg:0.386, loss_mask:0.452, loss_objectness:0.557, loss_rpn_box_reg:0.966,
# Epoch 32 [3.2:.2f] took 21.12 s: training loss 1.605, val_loss: 0.910,  loss_classifier:0.04, loss_box_reg:0.06, loss_mask:0.23, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.217 s: total:2.346,  loss_classifier:0.076, loss_box_reg:0.769, loss_mask:0.905, loss_objectness:0.911, loss_rpn_box_reg:2.346,
# 	Iteration 40 [50.00%] took 0.234 s: total:1.479,  loss_classifier:0.063, loss_box_reg:0.596, loss_mask:0.688, loss_objectness:0.916, loss_rpn_box_reg:1.479,
# 	Iteration 60 [75.00%] took 0.291 s: total:1.452,  loss_classifier:0.071, loss_box_reg:0.585, loss_mask:0.665, loss_objectness:0.752, loss_rpn_box_reg:1.452,
# 	Iteration 80 [100.00%] took 0.255 s: total:1.272,  loss_classifier:0.057, loss_box_reg:0.643, loss_mask:0.750, loss_objectness:0.751, loss_rpn_box_reg:1.272,
# Epoch 33 [3.3:.2f] took 20.36 s: training loss 1.532, val_loss: 0.860,  loss_classifier:0.05, loss_box_reg:0.06, loss_mask:0.21, loss_objectness:0.02, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.233 s: total:1.780,  loss_classifier:0.047, loss_box_reg:0.507, loss_mask:0.609, loss_objectness:0.913, loss_rpn_box_reg:1.780,
# 	Iteration 40 [50.00%] took 0.255 s: total:1.715,  loss_classifier:0.062, loss_box_reg:0.745, loss_mask:0.846, loss_objectness:0.898, loss_rpn_box_reg:1.715,
# 	Iteration 60 [75.00%] took 0.178 s: total:0.563,  loss_classifier:0.032, loss_box_reg:0.147, loss_mask:0.223, loss_objectness:0.226, loss_rpn_box_reg:0.563,
# 	Iteration 80 [100.00%] took 0.221 s: total:2.292,  loss_classifier:0.055, loss_box_reg:0.533, loss_mask:0.620, loss_objectness:0.906, loss_rpn_box_reg:2.292,
# Epoch 34 [3.4:.2f] took 20.18 s: training loss 1.553, val_loss: 0.894,  loss_classifier:0.06, loss_box_reg:0.07, loss_mask:0.20, loss_objectness:0.00, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.196 s: total:0.521,  loss_classifier:0.043, loss_box_reg:0.234, loss_mask:0.328, loss_objectness:0.335, loss_rpn_box_reg:0.521,
# 	Iteration 40 [50.00%] took 0.211 s: total:1.637,  loss_classifier:0.070, loss_box_reg:0.658, loss_mask:0.816, loss_objectness:0.837, loss_rpn_box_reg:1.637,
# 	Iteration 60 [75.00%] took 0.253 s: total:0.992,  loss_classifier:0.040, loss_box_reg:0.395, loss_mask:0.521, loss_objectness:0.599, loss_rpn_box_reg:0.992,
# 	Iteration 80 [100.00%] took 0.224 s: total:3.467,  loss_classifier:0.083, loss_box_reg:0.742, loss_mask:0.856, loss_objectness:0.909, loss_rpn_box_reg:3.467,
# Epoch 35 [3.5:.2f] took 20.46 s: training loss 1.548, val_loss: 0.806,  loss_classifier:0.06, loss_box_reg:0.08, loss_mask:0.23, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.251 s: total:3.116,  loss_classifier:0.077, loss_box_reg:0.927, loss_mask:1.042, loss_objectness:1.134, loss_rpn_box_reg:3.116,
# 	Iteration 40 [50.00%] took 0.253 s: total:1.128,  loss_classifier:0.078, loss_box_reg:0.575, loss_mask:0.668, loss_objectness:0.676, loss_rpn_box_reg:1.128,
# 	Iteration 60 [75.00%] took 0.218 s: total:1.089,  loss_classifier:0.046, loss_box_reg:0.380, loss_mask:0.479, loss_objectness:0.535, loss_rpn_box_reg:1.089,
# 	Iteration 80 [100.00%] took 0.222 s: total:0.937,  loss_classifier:0.055, loss_box_reg:0.566, loss_mask:0.669, loss_objectness:0.671, loss_rpn_box_reg:0.937,
# Epoch 36 [3.6:.2f] took 20.42 s: training loss 1.498, val_loss: 1.001,  loss_classifier:0.07, loss_box_reg:0.07, loss_mask:0.21, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.199 s: total:0.673,  loss_classifier:0.038, loss_box_reg:0.206, loss_mask:0.288, loss_objectness:0.305, loss_rpn_box_reg:0.673,
# 	Iteration 40 [50.00%] took 0.247 s: total:1.040,  loss_classifier:0.034, loss_box_reg:0.274, loss_mask:0.372, loss_objectness:0.469, loss_rpn_box_reg:1.040,
# 	Iteration 60 [75.00%] took 0.201 s: total:0.462,  loss_classifier:0.030, loss_box_reg:0.210, loss_mask:0.300, loss_objectness:0.367, loss_rpn_box_reg:0.462,
# 	Iteration 80 [100.00%] took 0.237 s: total:2.288,  loss_classifier:0.073, loss_box_reg:0.546, loss_mask:0.628, loss_objectness:0.995, loss_rpn_box_reg:2.288,
# Epoch 37 [3.7:.2f] took 20.43 s: training loss 1.465, val_loss: 0.955,  loss_classifier:0.04, loss_box_reg:0.07, loss_mask:0.21, loss_objectness:0.00, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.215 s: total:1.579,  loss_classifier:0.054, loss_box_reg:0.449, loss_mask:0.545, loss_objectness:0.887, loss_rpn_box_reg:1.579,
# 	Iteration 40 [50.00%] took 0.215 s: total:1.130,  loss_classifier:0.080, loss_box_reg:0.550, loss_mask:0.674, loss_objectness:0.697, loss_rpn_box_reg:1.130,
# 	Iteration 60 [75.00%] took 0.254 s: total:2.303,  loss_classifier:0.090, loss_box_reg:0.713, loss_mask:0.818, loss_objectness:0.955, loss_rpn_box_reg:2.303,
# 	Iteration 80 [100.00%] took 0.254 s: total:1.746,  loss_classifier:0.054, loss_box_reg:0.398, loss_mask:0.542, loss_objectness:0.572, loss_rpn_box_reg:1.746,
# Epoch 38 [3.8:.2f] took 20.37 s: training loss 1.834, val_loss: 1.193,  loss_classifier:0.06, loss_box_reg:0.07, loss_mask:0.24, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.273 s: total:3.229,  loss_classifier:0.066, loss_box_reg:0.986, loss_mask:1.112, loss_objectness:1.122, loss_rpn_box_reg:3.229,
# 	Iteration 40 [50.00%] took 0.201 s: total:0.935,  loss_classifier:0.064, loss_box_reg:0.359, loss_mask:0.460, loss_objectness:0.463, loss_rpn_box_reg:0.935,
# 	Iteration 60 [75.00%] took 0.255 s: total:1.074,  loss_classifier:0.038, loss_box_reg:0.377, loss_mask:0.460, loss_objectness:0.605, loss_rpn_box_reg:1.074,
# 	Iteration 80 [100.00%] took 0.209 s: total:0.767,  loss_classifier:0.037, loss_box_reg:0.222, loss_mask:0.325, loss_objectness:0.329, loss_rpn_box_reg:0.767,
# Epoch 39 [3.9:.2f] took 20.33 s: training loss 1.576, val_loss: 0.833,  loss_classifier:0.06, loss_box_reg:0.07, loss_mask:0.22, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.215 s: total:0.977,  loss_classifier:0.080, loss_box_reg:0.437, loss_mask:0.540, loss_objectness:0.548, loss_rpn_box_reg:0.977,
# 	Iteration 40 [50.00%] took 0.232 s: total:2.319,  loss_classifier:0.058, loss_box_reg:0.355, loss_mask:0.427, loss_objectness:0.437, loss_rpn_box_reg:2.319,
# 	Iteration 60 [75.00%] took 0.220 s: total:1.623,  loss_classifier:0.074, loss_box_reg:0.692, loss_mask:0.793, loss_objectness:0.836, loss_rpn_box_reg:1.623,
# 	Iteration 80 [100.00%] took 0.208 s: total:0.698,  loss_classifier:0.041, loss_box_reg:0.250, loss_mask:0.332, loss_objectness:0.333, loss_rpn_box_reg:0.698,
# Epoch 40 [4.0:.2f] took 20.45 s: training loss 1.396, val_loss: 0.966,  loss_classifier:0.06, loss_box_reg:0.08, loss_mask:0.21, loss_objectness:0.00, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.192 s: total:0.594,  loss_classifier:0.044, loss_box_reg:0.250, loss_mask:0.335, loss_objectness:0.344, loss_rpn_box_reg:0.594,
# 	Iteration 40 [50.00%] took 0.250 s: total:1.477,  loss_classifier:0.053, loss_box_reg:0.444, loss_mask:0.508, loss_objectness:0.556, loss_rpn_box_reg:1.477,
# 	Iteration 60 [75.00%] took 0.223 s: total:0.749,  loss_classifier:0.033, loss_box_reg:0.290, loss_mask:0.402, loss_objectness:0.403, loss_rpn_box_reg:0.749,
# 	Iteration 80 [100.00%] took 0.232 s: total:1.280,  loss_classifier:0.082, loss_box_reg:0.573, loss_mask:0.665, loss_objectness:0.698, loss_rpn_box_reg:1.280,
# Epoch 41 [4.1:.2f] took 21.78 s: training loss 1.403, val_loss: 0.748,  loss_classifier:0.06, loss_box_reg:0.07, loss_mask:0.21, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.25 s
# 	Iteration 20 [25.00%] took 0.229 s: total:1.210,  loss_classifier:0.068, loss_box_reg:0.405, loss_mask:0.526, loss_objectness:0.533, loss_rpn_box_reg:1.210,
# 	Iteration 40 [50.00%] took 0.190 s: total:1.239,  loss_classifier:0.060, loss_box_reg:0.410, loss_mask:0.501, loss_objectness:0.542, loss_rpn_box_reg:1.239,
# 	Iteration 60 [75.00%] took 0.263 s: total:1.375,  loss_classifier:0.060, loss_box_reg:0.619, loss_mask:0.705, loss_objectness:0.810, loss_rpn_box_reg:1.375,
# 	Iteration 80 [100.00%] took 0.257 s: total:1.537,  loss_classifier:0.042, loss_box_reg:0.422, loss_mask:0.501, loss_objectness:0.504, loss_rpn_box_reg:1.537,
# Epoch 42 [4.2:.2f] took 20.43 s: training loss 1.308, val_loss: 1.111,  loss_classifier:0.05, loss_box_reg:0.07, loss_mask:0.21, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.272 s: total:1.572,  loss_classifier:0.077, loss_box_reg:0.591, loss_mask:0.680, loss_objectness:0.782, loss_rpn_box_reg:1.572,
# 	Iteration 40 [50.00%] took 0.257 s: total:1.207,  loss_classifier:0.054, loss_box_reg:0.468, loss_mask:0.567, loss_objectness:0.606, loss_rpn_box_reg:1.207,
# 	Iteration 60 [75.00%] took 0.258 s: total:1.510,  loss_classifier:0.068, loss_box_reg:0.528, loss_mask:0.659, loss_objectness:0.691, loss_rpn_box_reg:1.510,
# 	Iteration 80 [100.00%] took 0.207 s: total:0.712,  loss_classifier:0.031, loss_box_reg:0.345, loss_mask:0.429, loss_objectness:0.450, loss_rpn_box_reg:0.712,
# Epoch 43 [4.3:.2f] took 21.07 s: training loss 1.444, val_loss: 0.853,  loss_classifier:0.05, loss_box_reg:0.07, loss_mask:0.22, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.190 s: total:0.747,  loss_classifier:0.043, loss_box_reg:0.302, loss_mask:0.381, loss_objectness:0.383, loss_rpn_box_reg:0.747,
# 	Iteration 40 [50.00%] took 0.195 s: total:1.082,  loss_classifier:0.059, loss_box_reg:0.355, loss_mask:0.476, loss_objectness:0.486, loss_rpn_box_reg:1.082,
# 	Iteration 60 [75.00%] took 0.212 s: total:2.856,  loss_classifier:0.118, loss_box_reg:0.963, loss_mask:1.077, loss_objectness:1.214, loss_rpn_box_reg:2.856,
# 	Iteration 80 [100.00%] took 0.191 s: total:0.671,  loss_classifier:0.027, loss_box_reg:0.268, loss_mask:0.350, loss_objectness:0.356, loss_rpn_box_reg:0.671,
# Epoch 44 [4.4:.2f] took 21.19 s: training loss 1.298, val_loss: 0.795,  loss_classifier:0.05, loss_box_reg:0.07, loss_mask:0.21, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.261 s: total:0.944,  loss_classifier:0.055, loss_box_reg:0.546, loss_mask:0.624, loss_objectness:0.625, loss_rpn_box_reg:0.944,
# 	Iteration 40 [50.00%] took 0.203 s: total:0.837,  loss_classifier:0.022, loss_box_reg:0.227, loss_mask:0.301, loss_objectness:0.457, loss_rpn_box_reg:0.837,
# 	Iteration 60 [75.00%] took 0.202 s: total:1.052,  loss_classifier:0.031, loss_box_reg:0.252, loss_mask:0.317, loss_objectness:0.319, loss_rpn_box_reg:1.052,
# 	Iteration 80 [100.00%] took 0.197 s: total:0.703,  loss_classifier:0.060, loss_box_reg:0.338, loss_mask:0.418, loss_objectness:0.429, loss_rpn_box_reg:0.703,
# Epoch 45 [4.5:.2f] took 21.48 s: training loss 1.231, val_loss: 0.757,  loss_classifier:0.05, loss_box_reg:0.07, loss_mask:0.21, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.262 s: total:2.351,  loss_classifier:0.056, loss_box_reg:0.637, loss_mask:0.726, loss_objectness:0.829, loss_rpn_box_reg:2.351,
# 	Iteration 40 [50.00%] took 0.260 s: total:1.274,  loss_classifier:0.056, loss_box_reg:0.520, loss_mask:0.600, loss_objectness:0.606, loss_rpn_box_reg:1.274,
# 	Iteration 60 [75.00%] took 0.264 s: total:1.814,  loss_classifier:0.069, loss_box_reg:0.670, loss_mask:0.761, loss_objectness:1.010, loss_rpn_box_reg:1.814,
# 	Iteration 80 [100.00%] took 0.248 s: total:1.166,  loss_classifier:0.073, loss_box_reg:0.590, loss_mask:0.672, loss_objectness:0.684, loss_rpn_box_reg:1.166,
# Epoch 46 [4.6:.2f] took 21.75 s: training loss 1.203, val_loss: 0.875,  loss_classifier:0.05, loss_box_reg:0.06, loss_mask:0.21, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.25 s
# 	Iteration 20 [25.00%] took 0.263 s: total:2.059,  loss_classifier:0.078, loss_box_reg:0.607, loss_mask:0.691, loss_objectness:0.744, loss_rpn_box_reg:2.059,
# 	Iteration 40 [50.00%] took 0.245 s: total:0.502,  loss_classifier:0.042, loss_box_reg:0.290, loss_mask:0.361, loss_objectness:0.366, loss_rpn_box_reg:0.502,
# 	Iteration 60 [75.00%] took 0.223 s: total:2.004,  loss_classifier:0.098, loss_box_reg:0.823, loss_mask:0.933, loss_objectness:1.204, loss_rpn_box_reg:2.004,
# 	Iteration 80 [100.00%] took 0.234 s: total:1.498,  loss_classifier:0.072, loss_box_reg:0.657, loss_mask:0.772, loss_objectness:0.783, loss_rpn_box_reg:1.498,
# Epoch 47 [4.7:.2f] took 21.72 s: training loss 1.189, val_loss: 0.758,  loss_classifier:0.05, loss_box_reg:0.07, loss_mask:0.21, loss_objectness:0.00, loss_rpn_box_reg:0.01,, each iteration took 0.25 s
# 	Iteration 20 [25.00%] took 0.255 s: total:0.958,  loss_classifier:0.049, loss_box_reg:0.439, loss_mask:0.541, loss_objectness:0.555, loss_rpn_box_reg:0.958,
# 	Iteration 40 [50.00%] took 0.187 s: total:1.203,  loss_classifier:0.030, loss_box_reg:0.371, loss_mask:0.513, loss_objectness:0.527, loss_rpn_box_reg:1.203,
# 	Iteration 60 [75.00%] took 0.252 s: total:1.255,  loss_classifier:0.061, loss_box_reg:0.500, loss_mask:0.589, loss_objectness:0.598, loss_rpn_box_reg:1.255,
# 	Iteration 80 [100.00%] took 0.211 s: total:1.469,  loss_classifier:0.068, loss_box_reg:0.723, loss_mask:0.816, loss_objectness:0.873, loss_rpn_box_reg:1.469,
# Epoch 48 [4.8:.2f] took 21.42 s: training loss 1.219, val_loss: 0.890,  loss_classifier:0.05, loss_box_reg:0.07, loss_mask:0.22, loss_objectness:0.00, loss_rpn_box_reg:0.01,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.267 s: total:3.073,  loss_classifier:0.085, loss_box_reg:0.759, loss_mask:0.844, loss_objectness:0.930, loss_rpn_box_reg:3.073,
# 	Iteration 40 [50.00%] took 0.209 s: total:1.174,  loss_classifier:0.039, loss_box_reg:0.432, loss_mask:0.561, loss_objectness:0.568, loss_rpn_box_reg:1.174,
# 	Iteration 60 [75.00%] took 0.245 s: total:1.196,  loss_classifier:0.076, loss_box_reg:0.588, loss_mask:0.689, loss_objectness:0.701, loss_rpn_box_reg:1.196,
# 	Iteration 80 [100.00%] took 0.208 s: total:0.893,  loss_classifier:0.064, loss_box_reg:0.485, loss_mask:0.613, loss_objectness:0.657, loss_rpn_box_reg:0.893,
# Epoch 49 [4.9:.2f] took 20.59 s: training loss 1.138, val_loss: 0.971,  loss_classifier:0.05, loss_box_reg:0.07, loss_mask:0.22, loss_objectness:0.00, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.276 s: total:1.335,  loss_classifier:0.056, loss_box_reg:0.543, loss_mask:0.616, loss_objectness:0.720, loss_rpn_box_reg:1.335,
# 	Iteration 40 [50.00%] took 0.252 s: total:1.592,  loss_classifier:0.062, loss_box_reg:0.712, loss_mask:0.818, loss_objectness:0.827, loss_rpn_box_reg:1.592,
# 	Iteration 60 [75.00%] took 0.199 s: total:0.285,  loss_classifier:0.015, loss_box_reg:0.145, loss_mask:0.229, loss_objectness:0.241, loss_rpn_box_reg:0.285,
# 	Iteration 80 [100.00%] took 0.261 s: total:1.881,  loss_classifier:0.073, loss_box_reg:0.567, loss_mask:0.687, loss_objectness:0.725, loss_rpn_box_reg:1.881,
# Epoch 50 [5.0:.2f] took 20.55 s: training loss 1.051, val_loss: 0.701,  loss_classifier:0.04, loss_box_reg:0.07, loss_mask:0.20, loss_objectness:0.00, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.360 s: total:0.312,  loss_classifier:0.025, loss_box_reg:0.141, loss_mask:0.220, loss_objectness:0.220, loss_rpn_box_reg:0.312,
# 	Iteration 40 [50.00%] took 0.259 s: total:1.394,  loss_classifier:0.039, loss_box_reg:0.456, loss_mask:0.541, loss_objectness:0.547, loss_rpn_box_reg:1.394,
# 	Iteration 60 [75.00%] took 0.182 s: total:1.017,  loss_classifier:0.047, loss_box_reg:0.343, loss_mask:0.456, loss_objectness:0.542, loss_rpn_box_reg:1.017,
# 	Iteration 80 [100.00%] took 0.260 s: total:1.047,  loss_classifier:0.043, loss_box_reg:0.382, loss_mask:0.454, loss_objectness:0.500, loss_rpn_box_reg:1.047,
# Epoch 51 [5.1:.2f] took 23.34 s: training loss 1.007, val_loss: 0.794,  loss_classifier:0.04, loss_box_reg:0.06, loss_mask:0.23, loss_objectness:0.00, loss_rpn_box_reg:0.01,, each iteration took 0.27 s
# 	Iteration 20 [25.00%] took 0.200 s: total:0.734,  loss_classifier:0.027, loss_box_reg:0.238, loss_mask:0.298, loss_objectness:0.302, loss_rpn_box_reg:0.734,
# 	Iteration 40 [50.00%] took 0.223 s: total:0.620,  loss_classifier:0.040, loss_box_reg:0.321, loss_mask:0.400, loss_objectness:0.400, loss_rpn_box_reg:0.620,
# 	Iteration 60 [75.00%] took 0.239 s: total:1.830,  loss_classifier:0.089, loss_box_reg:0.769, loss_mask:0.917, loss_objectness:0.921, loss_rpn_box_reg:1.830,
# 	Iteration 80 [100.00%] took 0.268 s: total:2.417,  loss_classifier:0.070, loss_box_reg:0.923, loss_mask:1.030, loss_objectness:1.041, loss_rpn_box_reg:2.417,
# Epoch 52 [5.2:.2f] took 20.30 s: training loss 0.974, val_loss: 0.836,  loss_classifier:0.04, loss_box_reg:0.06, loss_mask:0.20, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.270 s: total:1.747,  loss_classifier:0.093, loss_box_reg:0.731, loss_mask:0.872, loss_objectness:0.895, loss_rpn_box_reg:1.747,
# 	Iteration 40 [50.00%] took 0.192 s: total:0.598,  loss_classifier:0.047, loss_box_reg:0.181, loss_mask:0.257, loss_objectness:0.532, loss_rpn_box_reg:0.598,
# 	Iteration 60 [75.00%] took 0.273 s: total:1.061,  loss_classifier:0.049, loss_box_reg:0.374, loss_mask:0.451, loss_objectness:0.482, loss_rpn_box_reg:1.061,
# 	Iteration 80 [100.00%] took 0.256 s: total:0.669,  loss_classifier:0.035, loss_box_reg:0.321, loss_mask:0.400, loss_objectness:0.406, loss_rpn_box_reg:0.669,
# Epoch 53 [5.3:.2f] took 20.52 s: training loss 1.019, val_loss: 1.130,  loss_classifier:0.05, loss_box_reg:0.07, loss_mask:0.21, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.227 s: total:1.091,  loss_classifier:0.061, loss_box_reg:0.575, loss_mask:0.665, loss_objectness:0.677, loss_rpn_box_reg:1.091,
# 	Iteration 40 [50.00%] took 0.209 s: total:0.461,  loss_classifier:0.036, loss_box_reg:0.204, loss_mask:0.273, loss_objectness:0.290, loss_rpn_box_reg:0.461,
# 	Iteration 60 [75.00%] took 0.209 s: total:0.906,  loss_classifier:0.053, loss_box_reg:0.449, loss_mask:0.521, loss_objectness:0.530, loss_rpn_box_reg:0.906,
# 	Iteration 80 [100.00%] took 0.227 s: total:0.510,  loss_classifier:0.033, loss_box_reg:0.141, loss_mask:0.204, loss_objectness:0.207, loss_rpn_box_reg:0.510,
# Epoch 54 [5.4:.2f] took 20.46 s: training loss 0.960, val_loss: 0.958,  loss_classifier:0.05, loss_box_reg:0.07, loss_mask:0.19, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.274 s: total:2.549,  loss_classifier:0.112, loss_box_reg:0.941, loss_mask:1.047, loss_objectness:1.150, loss_rpn_box_reg:2.549,
# 	Iteration 40 [50.00%] took 0.257 s: total:0.758,  loss_classifier:0.038, loss_box_reg:0.430, loss_mask:0.521, loss_objectness:0.522, loss_rpn_box_reg:0.758,
# 	Iteration 60 [75.00%] took 0.253 s: total:0.841,  loss_classifier:0.040, loss_box_reg:0.326, loss_mask:0.400, loss_objectness:0.402, loss_rpn_box_reg:0.841,
# 	Iteration 80 [100.00%] took 0.233 s: total:0.554,  loss_classifier:0.049, loss_box_reg:0.295, loss_mask:0.366, loss_objectness:0.368, loss_rpn_box_reg:0.554,
# Epoch 55 [5.5:.2f] took 20.99 s: training loss 0.885, val_loss: 0.769,  loss_classifier:0.05, loss_box_reg:0.06, loss_mask:0.20, loss_objectness:0.00, loss_rpn_box_reg:0.01,, each iteration took 0.24 s
# 	Iteration 20 [25.00%] took 0.250 s: total:0.737,  loss_classifier:0.041, loss_box_reg:0.372, loss_mask:0.455, loss_objectness:0.456, loss_rpn_box_reg:0.737,
# 	Iteration 40 [50.00%] took 0.263 s: total:1.663,  loss_classifier:0.087, loss_box_reg:0.703, loss_mask:0.811, loss_objectness:0.831, loss_rpn_box_reg:1.663,
# 	Iteration 60 [75.00%] took 0.265 s: total:1.350,  loss_classifier:0.059, loss_box_reg:0.532, loss_mask:0.625, loss_objectness:0.632, loss_rpn_box_reg:1.350,
# 	Iteration 80 [100.00%] took 0.212 s: total:0.392,  loss_classifier:0.035, loss_box_reg:0.257, loss_mask:0.317, loss_objectness:0.320, loss_rpn_box_reg:0.392,
# Epoch 56 [5.6:.2f] took 20.28 s: training loss 0.914, val_loss: 0.861,  loss_classifier:0.05, loss_box_reg:0.06, loss_mask:0.21, loss_objectness:0.00, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.257 s: total:1.247,  loss_classifier:0.071, loss_box_reg:0.467, loss_mask:0.579, loss_objectness:0.593, loss_rpn_box_reg:1.247,
# 	Iteration 40 [50.00%] took 0.283 s: total:1.024,  loss_classifier:0.101, loss_box_reg:0.601, loss_mask:0.691, loss_objectness:0.695, loss_rpn_box_reg:1.024,
# 	Iteration 60 [75.00%] took 0.253 s: total:0.766,  loss_classifier:0.040, loss_box_reg:0.303, loss_mask:0.369, loss_objectness:0.599, loss_rpn_box_reg:0.766,
# 	Iteration 80 [100.00%] took 0.259 s: total:1.104,  loss_classifier:0.058, loss_box_reg:0.447, loss_mask:0.535, loss_objectness:0.537, loss_rpn_box_reg:1.104,
# Epoch 57 [5.7:.2f] took 20.57 s: training loss 0.920, val_loss: 0.889,  loss_classifier:0.04, loss_box_reg:0.06, loss_mask:0.23, loss_objectness:0.00, loss_rpn_box_reg:0.01,, each iteration took 0.23 s
# 	Iteration 20 [25.00%] took 0.215 s: total:0.482,  loss_classifier:0.028, loss_box_reg:0.217, loss_mask:0.297, loss_objectness:0.309, loss_rpn_box_reg:0.482,
# 	Iteration 40 [50.00%] took 0.195 s: total:0.295,  loss_classifier:0.034, loss_box_reg:0.137, loss_mask:0.200, loss_objectness:0.201, loss_rpn_box_reg:0.295,
# ...
# 	Iteration 80 [100.00%] took 0.439 s: total:0.125,  loss_classifier:0.012, loss_box_reg:0.044, loss_mask:0.081, loss_objectness:0.081, loss_rpn_box_reg:0.125,
# Epoch 978 [97.8:.2f] took 31.72 s: training loss 0.109, val_loss: 0.566,  loss_classifier:0.10, loss_box_reg:0.06, loss_mask:0.26, loss_objectness:0.02, loss_rpn_box_reg:0.01,, each iteration took 0.37 s
# 	Iteration 20 [25.00%] took 0.320 s: total:0.058,  loss_classifier:0.002, loss_box_reg:0.014, loss_mask:0.048, loss_objectness:0.048, loss_rpn_box_reg:0.058,
# 	Iteration 40 [50.00%] took 0.315 s: total:0.481,  loss_classifier:0.008, loss_box_reg:0.041, loss_mask:0.122, loss_objectness:0.464, loss_rpn_box_reg:0.481,
# 	Iteration 60 [75.00%] took 0.368 s: total:0.196,  loss_classifier:0.021, loss_box_reg:0.095, loss_mask:0.134, loss_objectness:0.136, loss_rpn_box_reg:0.196,
# 	Iteration 80 [100.00%] took 0.444 s: total:0.091,  loss_classifier:0.008, loss_box_reg:0.034, loss_mask:0.070, loss_objectness:0.071, loss_rpn_box_reg:0.091,
# Epoch 979 [97.9:.2f] took 33.66 s: training loss 0.114, val_loss: 0.515,  loss_classifier:0.08, loss_box_reg:0.06, loss_mask:0.27, loss_objectness:0.05, loss_rpn_box_reg:0.01,, each iteration took 0.39 s
# 	Iteration 20 [25.00%] took 0.454 s: total:0.130,  loss_classifier:0.008, loss_box_reg:0.038, loss_mask:0.089, loss_objectness:0.090, loss_rpn_box_reg:0.130,
# 	Iteration 40 [50.00%] took 0.446 s: total:0.174,  loss_classifier:0.018, loss_box_reg:0.079, loss_mask:0.119, loss_objectness:0.119, loss_rpn_box_reg:0.174,
# 	Iteration 60 [75.00%] took 0.372 s: total:0.167,  loss_classifier:0.006, loss_box_reg:0.075, loss_mask:0.120, loss_objectness:0.121, loss_rpn_box_reg:0.167,
# 	Iteration 80 [100.00%] took 0.375 s: total:0.084,  loss_classifier:0.006, loss_box_reg:0.031, loss_mask:0.072, loss_objectness:0.073, loss_rpn_box_reg:0.084,
# Epoch 980 [98.0:.2f] took 33.72 s: training loss 0.106, val_loss: 0.518,  loss_classifier:0.06, loss_box_reg:0.05, loss_mask:0.27, loss_objectness:0.02, loss_rpn_box_reg:0.01,, each iteration took 0.40 s
# 	Iteration 20 [25.00%] took 0.374 s: total:0.089,  loss_classifier:0.006, loss_box_reg:0.038, loss_mask:0.076, loss_objectness:0.076, loss_rpn_box_reg:0.089,
# 	Iteration 40 [50.00%] took 0.333 s: total:0.117,  loss_classifier:0.012, loss_box_reg:0.050, loss_mask:0.085, loss_objectness:0.086, loss_rpn_box_reg:0.117,
# 	Iteration 60 [75.00%] took 0.272 s: total:0.063,  loss_classifier:0.005, loss_box_reg:0.020, loss_mask:0.054, loss_objectness:0.054, loss_rpn_box_reg:0.063,
# 	Iteration 80 [100.00%] took 0.300 s: total:0.078,  loss_classifier:0.006, loss_box_reg:0.032, loss_mask:0.066, loss_objectness:0.066, loss_rpn_box_reg:0.078,
# Epoch 981 [98.1:.2f] took 28.53 s: training loss 0.110, val_loss: 0.517,  loss_classifier:0.06, loss_box_reg:0.05, loss_mask:0.27, loss_objectness:0.02, loss_rpn_box_reg:0.01,, each iteration took 0.33 s
# 	Iteration 20 [25.00%] took 0.328 s: total:0.127,  loss_classifier:0.010, loss_box_reg:0.053, loss_mask:0.090, loss_objectness:0.091, loss_rpn_box_reg:0.127,
# 	Iteration 40 [50.00%] took 0.280 s: total:0.094,  loss_classifier:0.003, loss_box_reg:0.022, loss_mask:0.057, loss_objectness:0.057, loss_rpn_box_reg:0.094,
# 	Iteration 60 [75.00%] took 0.304 s: total:0.078,  loss_classifier:0.009, loss_box_reg:0.033, loss_mask:0.066, loss_objectness:0.066, loss_rpn_box_reg:0.078,
# 	Iteration 80 [100.00%] took 0.294 s: total:0.133,  loss_classifier:0.007, loss_box_reg:0.028, loss_mask:0.068, loss_objectness:0.068, loss_rpn_box_reg:0.133,
# Epoch 982 [98.2:.2f] took 30.72 s: training loss 0.134, val_loss: 0.463,  loss_classifier:0.06, loss_box_reg:0.06, loss_mask:0.24, loss_objectness:0.02, loss_rpn_box_reg:0.01,, each iteration took 0.36 s
# 	Iteration 20 [25.00%] took 0.299 s: total:0.110,  loss_classifier:0.005, loss_box_reg:0.027, loss_mask:0.066, loss_objectness:0.066, loss_rpn_box_reg:0.110,
# 	Iteration 40 [50.00%] took 0.306 s: total:0.129,  loss_classifier:0.007, loss_box_reg:0.056, loss_mask:0.098, loss_objectness:0.098, loss_rpn_box_reg:0.129,
# 	Iteration 60 [75.00%] took 0.385 s: total:0.287,  loss_classifier:0.022, loss_box_reg:0.150, loss_mask:0.196, loss_objectness:0.197, loss_rpn_box_reg:0.287,
# 	Iteration 80 [100.00%] took 0.394 s: total:0.162,  loss_classifier:0.015, loss_box_reg:0.078, loss_mask:0.122, loss_objectness:0.123, loss_rpn_box_reg:0.162,
# Epoch 983 [98.3:.2f] took 29.47 s: training loss 0.160, val_loss: 0.526,  loss_classifier:0.06, loss_box_reg:0.06, loss_mask:0.25, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.34 s
# 	Iteration 20 [25.00%] took 0.377 s: total:0.156,  loss_classifier:0.008, loss_box_reg:0.082, loss_mask:0.122, loss_objectness:0.122, loss_rpn_box_reg:0.156,
# 	Iteration 40 [50.00%] took 0.329 s: total:0.111,  loss_classifier:0.006, loss_box_reg:0.037, loss_mask:0.077, loss_objectness:0.077, loss_rpn_box_reg:0.111,
# 	Iteration 60 [75.00%] took 0.380 s: total:0.267,  loss_classifier:0.016, loss_box_reg:0.092, loss_mask:0.137, loss_objectness:0.138, loss_rpn_box_reg:0.267,
# 	Iteration 80 [100.00%] took 0.351 s: total:0.095,  loss_classifier:0.010, loss_box_reg:0.045, loss_mask:0.079, loss_objectness:0.079, loss_rpn_box_reg:0.095,
# Epoch 984 [98.4:.2f] took 30.41 s: training loss 0.167, val_loss: 0.705,  loss_classifier:0.08, loss_box_reg:0.07, loss_mask:0.27, loss_objectness:0.02, loss_rpn_box_reg:0.01,, each iteration took 0.35 s
# 	Iteration 20 [25.00%] took 0.281 s: total:0.117,  loss_classifier:0.007, loss_box_reg:0.048, loss_mask:0.093, loss_objectness:0.093, loss_rpn_box_reg:0.117,
# 	Iteration 40 [50.00%] took 0.295 s: total:0.100,  loss_classifier:0.011, loss_box_reg:0.044, loss_mask:0.085, loss_objectness:0.085, loss_rpn_box_reg:0.100,
# 	Iteration 60 [75.00%] took 0.297 s: total:0.168,  loss_classifier:0.022, loss_box_reg:0.069, loss_mask:0.106, loss_objectness:0.106, loss_rpn_box_reg:0.168,
# 	Iteration 80 [100.00%] took 0.279 s: total:0.135,  loss_classifier:0.006, loss_box_reg:0.050, loss_mask:0.087, loss_objectness:0.088, loss_rpn_box_reg:0.135,
# Epoch 985 [98.5:.2f] took 28.85 s: training loss 0.162, val_loss: 0.611,  loss_classifier:0.06, loss_box_reg:0.06, loss_mask:0.25, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.33 s
# 	Iteration 20 [25.00%] took 0.301 s: total:0.107,  loss_classifier:0.011, loss_box_reg:0.047, loss_mask:0.084, loss_objectness:0.084, loss_rpn_box_reg:0.107,
# 	Iteration 40 [50.00%] took 0.356 s: total:0.738,  loss_classifier:0.021, loss_box_reg:0.126, loss_mask:0.171, loss_objectness:0.191, loss_rpn_box_reg:0.738,
# 	Iteration 60 [75.00%] took 0.318 s: total:0.215,  loss_classifier:0.010, loss_box_reg:0.066, loss_mask:0.105, loss_objectness:0.105, loss_rpn_box_reg:0.215,
# 	Iteration 80 [100.00%] took 0.357 s: total:0.176,  loss_classifier:0.012, loss_box_reg:0.062, loss_mask:0.103, loss_objectness:0.104, loss_rpn_box_reg:0.176,
# Epoch 986 [98.6:.2f] took 29.42 s: training loss 0.173, val_loss: 0.565,  loss_classifier:0.06, loss_box_reg:0.07, loss_mask:0.24, loss_objectness:0.02, loss_rpn_box_reg:0.01,, each iteration took 0.34 s
# 	Iteration 20 [25.00%] took 0.322 s: total:0.132,  loss_classifier:0.017, loss_box_reg:0.055, loss_mask:0.093, loss_objectness:0.094, loss_rpn_box_reg:0.132,
# 	Iteration 40 [50.00%] took 0.282 s: total:0.076,  loss_classifier:0.003, loss_box_reg:0.030, loss_mask:0.064, loss_objectness:0.065, loss_rpn_box_reg:0.076,
# 	Iteration 60 [75.00%] took 0.307 s: total:0.096,  loss_classifier:0.012, loss_box_reg:0.036, loss_mask:0.073, loss_objectness:0.073, loss_rpn_box_reg:0.096,
# 	Iteration 80 [100.00%] took 0.282 s: total:0.134,  loss_classifier:0.008, loss_box_reg:0.069, loss_mask:0.104, loss_objectness:0.105, loss_rpn_box_reg:0.134,
# Epoch 987 [98.7:.2f] took 29.28 s: training loss 0.157, val_loss: 0.644,  loss_classifier:0.06, loss_box_reg:0.06, loss_mask:0.24, loss_objectness:0.03, loss_rpn_box_reg:0.01,, each iteration took 0.34 s
# 	Iteration 20 [25.00%] took 0.316 s: total:0.113,  loss_classifier:0.003, loss_box_reg:0.032, loss_mask:0.069, loss_objectness:0.069, loss_rpn_box_reg:0.113,
# 	Iteration 80 [100.00%] took 0.385 s: total:0.215,  loss_classifier:0.017, loss_box_reg:0.096, loss_mask:0.136, loss_objectness:0.137, loss_rpn_box_reg:0.215,
# Epoch 991 [99.1:.2f] took 28.78 s: training loss 0.157, val_loss: 0.600,  loss_classifier:0.07, loss_box_reg:0.06, loss_mask:0.29, loss_objectness:0.04, loss_rpn_box_reg:0.01,, each iteration took 0.33 s
# 	Iteration 20 [25.00%] took 0.417 s: total:0.142,  loss_classifier:0.005, loss_box_reg:0.045, loss_mask:0.080, loss_objectness:0.081, loss_rpn_box_reg:0.142,
# 	Iteration 40 [50.00%] took 0.313 s: total:0.071,  loss_classifier:0.002, loss_box_reg:0.015, loss_mask:0.053, loss_objectness:0.053, loss_rpn_box_reg:0.071,
# 	Iteration 60 [75.00%] took 0.480 s: total:0.404,  loss_classifier:0.015, loss_box_reg:0.076, loss_mask:0.127, loss_objectness:0.130, loss_rpn_box_reg:0.404,
# 	Iteration 80 [100.00%] took 0.345 s: total:0.190,  loss_classifier:0.008, loss_box_reg:0.058, loss_mask:0.098, loss_objectness:0.098, loss_rpn_box_reg:0.190,
# Epoch 992 [99.2:.2f] took 33.41 s: training loss 0.196, val_loss: 0.617,  loss_classifier:0.08, loss_box_reg:0.05, loss_mask:0.25, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.39 s
# 	Iteration 20 [25.00%] took 0.336 s: total:0.194,  loss_classifier:0.009, loss_box_reg:0.074, loss_mask:0.128, loss_objectness:0.129, loss_rpn_box_reg:0.194,
# 	Iteration 40 [50.00%] took 0.409 s: total:0.152,  loss_classifier:0.002, loss_box_reg:0.015, loss_mask:0.056, loss_objectness:0.118, loss_rpn_box_reg:0.152,
# 	Iteration 60 [75.00%] took 0.251 s: total:0.145,  loss_classifier:0.002, loss_box_reg:0.030, loss_mask:0.074, loss_objectness:0.087, loss_rpn_box_reg:0.145,
# 	Iteration 80 [100.00%] took 0.296 s: total:0.105,  loss_classifier:0.002, loss_box_reg:0.029, loss_mask:0.067, loss_objectness:0.067, loss_rpn_box_reg:0.105,
# Epoch 993 [99.3:.2f] took 30.95 s: training loss 0.202, val_loss: 0.535,  loss_classifier:0.06, loss_box_reg:0.06, loss_mask:0.24, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.36 s
# 	Iteration 20 [25.00%] took 0.357 s: total:0.113,  loss_classifier:0.013, loss_box_reg:0.047, loss_mask:0.086, loss_objectness:0.087, loss_rpn_box_reg:0.113,
# 	Iteration 40 [50.00%] took 0.356 s: total:0.110,  loss_classifier:0.003, loss_box_reg:0.030, loss_mask:0.073, loss_objectness:0.073, loss_rpn_box_reg:0.110,
# 	Iteration 60 [75.00%] took 0.355 s: total:0.117,  loss_classifier:0.012, loss_box_reg:0.054, loss_mask:0.093, loss_objectness:0.094, loss_rpn_box_reg:0.117,
# 	Iteration 80 [100.00%] took 0.363 s: total:0.162,  loss_classifier:0.009, loss_box_reg:0.060, loss_mask:0.099, loss_objectness:0.100, loss_rpn_box_reg:0.162,
# Epoch 994 [99.4:.2f] took 32.88 s: training loss 0.139, val_loss: 0.567,  loss_classifier:0.06, loss_box_reg:0.06, loss_mask:0.27, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.38 s
# 	Iteration 20 [25.00%] took 0.435 s: total:0.163,  loss_classifier:0.009, loss_box_reg:0.051, loss_mask:0.087, loss_objectness:0.088, loss_rpn_box_reg:0.163,
# 	Iteration 40 [50.00%] took 0.310 s: total:0.069,  loss_classifier:0.003, loss_box_reg:0.016, loss_mask:0.051, loss_objectness:0.052, loss_rpn_box_reg:0.069,
# 	Iteration 60 [75.00%] took 0.416 s: total:0.111,  loss_classifier:0.005, loss_box_reg:0.049, loss_mask:0.087, loss_objectness:0.088, loss_rpn_box_reg:0.111,
# 	Iteration 80 [100.00%] took 0.422 s: total:0.204,  loss_classifier:0.006, loss_box_reg:0.043, loss_mask:0.085, loss_objectness:0.087, loss_rpn_box_reg:0.204,
# Epoch 995 [99.5:.2f] took 31.87 s: training loss 0.134, val_loss: 0.515,  loss_classifier:0.05, loss_box_reg:0.05, loss_mask:0.26, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.37 s
# 	Iteration 20 [25.00%] took 0.287 s: total:0.076,  loss_classifier:0.001, loss_box_reg:0.023, loss_mask:0.058, loss_objectness:0.058, loss_rpn_box_reg:0.076,
# 	Iteration 40 [50.00%] took 0.349 s: total:0.128,  loss_classifier:0.005, loss_box_reg:0.022, loss_mask:0.058, loss_objectness:0.058, loss_rpn_box_reg:0.128,
# 	Iteration 60 [75.00%] took 0.472 s: total:0.139,  loss_classifier:0.010, loss_box_reg:0.051, loss_mask:0.096, loss_objectness:0.096, loss_rpn_box_reg:0.139,
# 	Iteration 80 [100.00%] took 0.370 s: total:0.093,  loss_classifier:0.007, loss_box_reg:0.030, loss_mask:0.067, loss_objectness:0.067, loss_rpn_box_reg:0.093,
# Epoch 996 [99.6:.2f] took 30.95 s: training loss 0.120, val_loss: 0.524,  loss_classifier:0.05, loss_box_reg:0.06, loss_mask:0.28, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.36 s
# 	Iteration 20 [25.00%] took 0.300 s: total:0.365,  loss_classifier:0.012, loss_box_reg:0.052, loss_mask:0.090, loss_objectness:0.321, loss_rpn_box_reg:0.365,
# 	Iteration 40 [50.00%] took 0.354 s: total:0.068,  loss_classifier:0.004, loss_box_reg:0.016, loss_mask:0.054, loss_objectness:0.054, loss_rpn_box_reg:0.068,
# 	Iteration 60 [75.00%] took 0.331 s: total:0.117,  loss_classifier:0.008, loss_box_reg:0.054, loss_mask:0.087, loss_objectness:0.087, loss_rpn_box_reg:0.117,
# 	Iteration 80 [100.00%] took 0.355 s: total:0.100,  loss_classifier:0.007, loss_box_reg:0.045, loss_mask:0.077, loss_objectness:0.078, loss_rpn_box_reg:0.100,
# Epoch 997 [99.7:.2f] took 31.38 s: training loss 0.123, val_loss: 0.546,  loss_classifier:0.06, loss_box_reg:0.06, loss_mask:0.26, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.37 s
# 	Iteration 20 [25.00%] took 0.335 s: total:0.106,  loss_classifier:0.010, loss_box_reg:0.051, loss_mask:0.086, loss_objectness:0.086, loss_rpn_box_reg:0.106,
# 	Iteration 40 [50.00%] took 0.304 s: total:0.069,  loss_classifier:0.003, loss_box_reg:0.020, loss_mask:0.055, loss_objectness:0.056, loss_rpn_box_reg:0.069,
# 	Iteration 60 [75.00%] took 0.416 s: total:0.092,  loss_classifier:0.007, loss_box_reg:0.041, loss_mask:0.078, loss_objectness:0.078, loss_rpn_box_reg:0.092,
# 	Iteration 80 [100.00%] took 0.381 s: total:0.061,  loss_classifier:0.003, loss_box_reg:0.021, loss_mask:0.055, loss_objectness:0.055, loss_rpn_box_reg:0.061,
# Epoch 998 [99.8:.2f] took 31.33 s: training loss 0.110, val_loss: 0.474,  loss_classifier:0.06, loss_box_reg:0.05, loss_mask:0.28, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.37 s
# 	Iteration 20 [25.00%] took 0.312 s: total:0.093,  loss_classifier:0.003, loss_box_reg:0.032, loss_mask:0.066, loss_objectness:0.069, loss_rpn_box_reg:0.093,
# 	Iteration 40 [50.00%] took 0.418 s: total:0.089,  loss_classifier:0.003, loss_box_reg:0.024, loss_mask:0.059, loss_objectness:0.060, loss_rpn_box_reg:0.089,
# 	Iteration 60 [75.00%] took 0.435 s: total:0.156,  loss_classifier:0.014, loss_box_reg:0.071, loss_mask:0.106, loss_objectness:0.107, loss_rpn_box_reg:0.156,
# 	Iteration 80 [100.00%] took 0.418 s: total:0.144,  loss_classifier:0.008, loss_box_reg:0.052, loss_mask:0.097, loss_objectness:0.098, loss_rpn_box_reg:0.144,
# Epoch 999 [99.9:.2f] took 32.93 s: training loss 0.118, val_loss: 0.725,  loss_classifier:0.07, loss_box_reg:0.05, loss_mask:0.26, loss_objectness:0.04, loss_rpn_box_reg:0.01,, each iteration took 0.39 s
# 	Iteration 20 [25.00%] took 0.363 s: total:0.154,  loss_classifier:0.007, loss_box_reg:0.047, loss_mask:0.087, loss_objectness:0.088, loss_rpn_box_reg:0.154,
# 	Iteration 40 [50.00%] took 0.416 s: total:0.120,  loss_classifier:0.006, loss_box_reg:0.043, loss_mask:0.081, loss_objectness:0.082, loss_rpn_box_reg:0.120,
# 	Iteration 60 [75.00%] took 0.351 s: total:0.133,  loss_classifier:0.012, loss_box_reg:0.042, loss_mask:0.079, loss_objectness:0.080, loss_rpn_box_reg:0.133,
# 	Iteration 80 [100.00%] took 0.410 s: total:0.092,  loss_classifier:0.009, loss_box_reg:0.033, loss_mask:0.066, loss_objectness:0.066, loss_rpn_box_reg:0.092,
# Epoch 1000 [100.0:.2f] took 31.45 s: training loss 0.119, val_loss: 0.585,  loss_classifier:0.08, loss_box_reg:0.06, loss_mask:0.27, loss_objectness:0.01, loss_rpn_box_reg:0.01,, each iteration took 0.37 s

# %%
# model.load_state_dict(torch.load('checkpoint.pth', weights_only=True))

# Our data are small but it seems we can continue training further since the graph below still shows
# that the model can still learn, i.e., underfit due to early training termination
fig, ax=plt.subplots(figsize=(4,4))
for name, losses in zip('train, validation'.split(','),[train_losses, val_losses]):
    losses=[l.detach().cpu() if isinstance(l, torch.Tensor) else l for l in losses]
    ax.plot(losses, label=name)
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
plt.legend(loc="upper right")

# %% [markdown]
# ### Inference
#
# Out test data is the same as validation data for this quick test on a small data, which is not how we should partition data typically

# %%
def alpha_bending(foreground, background, alpha):
    '''
    Args:
        foreground (Tensor): NxCxHxW image to be on the foreground
        background (Tensor): NxCxHxW image to be on the background
        alpha (float): opacity of the foreground
    '''
    background=background.to(torch.float32)
    foreground=foreground.to(torch.float32)
    C=max(background.shape[1], foreground.shape[1])
    output=torch.zeros(background.shape[0], C, *background.shape[-2:], dtype=background.dtype,
                       device=background.device)
    if foreground.shape[1]!=C: foreground=foreground.expand(foreground.shape[0],1,*foreground.shape[-2:])
    if background.shape[1]!=C: background=background.expand(background.shape[0],1,*background.shape[-2:])
    return background*(1.-alpha)+foreground*alpha

# %%
model.eval()
test_dataset=PennFudanDataset(root=os.path.join(main_dirpath, 'PennFudanPed'), image_dirname='PNGImages', mask_dirname='PedMasks',
                               annotation_dirname='Annotation', transforms=get_transform(is_train=False), indices=np.arange(160,170))

test_loader=torch.utils.data.DataLoader(val_dataset, batch_size=1,shuffle=False,collate_fn=utils.collate_fn)

# %%
all_input_images=[]
all_outputs=[]
for indx, (images, targets) in enumerate(test_loader):
    images=[im.to(device) for im in images]
    with torch.no_grad(): outputs=model(images)
    all_input_images.append(images)
    all_outputs.append(outputs)

# %%
import matplotlib.patches as patches

# visualize outputs

alpha=0.4
for i, (images,outputs) in enumerate(zip(all_input_images,all_outputs)):

    for image, output in zip(images, outputs):

        # turn heatmap to segmentation
        mask=(output['masks']>0.5).to(dtype=torch.uint8) # Nx1xHxW where N is the number of boxes
        # make binary mask RGB channel of cyan
        mask=torch.cat([torch.zeros_like(mask), mask, mask], dim=1) # NxCxHxW where C is RBG channels
        # convert CxHxW -> NxCxHxW
        background=image.unsqueeze(0).expand(output['masks'].shape[0], *image.shape)
        alpha_img=alpha_bending(foreground=mask, background=background, alpha=alpha)

        # boxes
        boxes=output['boxes'].cpu()
        x,y=boxes[:,0], boxes[:,1]
        size=boxes[:,2:]-boxes[:,:2]
        width, height=size[:,0], size[:,1]

        # scores
        scores=output['scores'].cpu()


        # visualize output
        fig, axes=plt.subplots(1, alpha_img.shape[0], figsize=(8,3))
        for i, al_im in enumerate(alpha_img):
            try: ax=axes[i]
            except: ax=axes
            ax.imshow(al_im.permute(1,2,0).cpu()) # CxHxW -> HxWxC
            rect = patches.Rectangle((x[i], y[i]), width[i], height[i], linewidth=2, edgecolor='c', facecolor='none')
            ax.add_patch(rect)
            ax.text(x[i]-1, y[i]-1, s=f'{scores[i]:.3f}', fontsize=8, fontweight='bold', color='c')
            ax.axis('off')
        plt.tight_layout(pad=0, w_pad=0, h_pad=0)
