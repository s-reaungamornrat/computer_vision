# %%
import os
import sys

from ultralytics import settings
from ultralytics.data.utils import check_det_dataset

# %%
print('settings ', settings.keys())
print('datasets_dir ', settings['datasets_dir'])
print('weights_dir ', settings['weights_dir'])
print('runs_dir ', settings['runs_dir'])
settings['datasets_dir']='D:/data/ultralytics'
settings['runs_dir']='D:/results/yolov11'
settings['weights_dir']=os.path.join(settings['runs_dir'], 'checkpoints')
# Out:
# settings  dict_keys(['settings_version', 'datasets_dir', 'weights_dir', 'runs_dir', 'uuid', 'sync', 'api_key', 'openai_api_key', 'clearml', 'comet', 'dvc', 'hub', 'mlflow', 'neptune', 'raytune', 'tensorboard', 'wandb', 'vscode_msg', 'openvino_msg'])
# datasets_dir  D:/data/ultralytics
# weights_dir  D:/results/yolov11\checkpoints
# runs_dir  D:/results/yolov11

# %%
dataset=check_det_dataset("coco-pose.yaml")
# Out:
# WARNING Dataset 'coco-pose.yaml' images not found, missing path 'D:\data\ultralytics\coco-pose\val2017.txt'
# Downloading https://ultralytics.com/assets/coco2017labels-pose.zip to 'D:\data\ultralytics\coco2017labels-pose.zip': 100% ━━━━━━━━━━━━ 37.7MB 1.3MB/s 28.7s28.6s<0.0ssss
# Unzipping D:\data\ultralytics\coco2017labels-pose.zip to D:\data\ultralytics\coco-pose...: 100% ━━━━━━━━━━━━ 58957/58957 243.4files/s 4:02<0.0s
# Downloading 3 file(s) with 3 threads to D:\data\ultralytics\coco-pose\images...
# Downloading http://images.cocodataset.org/zips/val2017.zip to 'D:\data\ultralytics\coco-pose\images\val2017.zip': 100% ━━━━━━━━━━━━ 777.8MB 5.3MB/s 2:25s 2:25<0.4s2:52049
# Unzipping D:\data\ultralytics\coco-pose\images\val2017.zip to D:\data\ultralytics\coco-pose\images\val2017...: 100% ━━━━━━━━━━━━ 5001/5001 736.5files/s 6.8s2<54:0640:3337
# Downloading http://images.cocodataset.org/zips/test2017.zip to 'D:\data\ultralytics\coco-pose\images\test2017.zip': 100% ━━━━━━━━━━━━ 6.2GB 7.3MB/s 14:234:23<0.1s:535642
# Unzipping D:\data\ultralytics\coco-pose\images\test2017.zip to D:\data\ultralytics\coco-pose\images\test2017...: 100% ━━━━━━━━━━━━ 40671/40671 878.5files/s 46.3s<0.0s
# Downloading http://images.cocodataset.org/zips/train2017.zip to 'D:\data\ultralytics\coco-pose\images\train2017.zip': 100% ━━━━━━━━━━━━ 18.0GB 8.0MB/s 38:1438:14<0.0ss236
# Unzipping D:\data\ultralytics\coco-pose\images\train2017.zip to D:\data\ultralytics\coco-pose\images\train2017...: 100% ━━━━━━━━━━━━ 118288/118288 933.3files/s 2:07<0.0s
# Dataset download success  (2696.7s), saved to D:\data\ultralytics
