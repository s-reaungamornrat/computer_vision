# %%
import os
import sys

from ultralytics import settings
from ultralytics.data.utils import check_det_dataset

# %%
print('settings ', settings.keys())
print('datasets_dir ', settings['datasets_dir'])
print('weights_dir ', settings['weights_dir'])
print('runs_dir ', settings['runs_dir'])
settings['datasets_dir']='D:/data/ultralytics'
settings['runs_dir']='D:/results/yolov11'
settings['weights_dir']=os.path.join(settings['runs_dir'], 'checkpoints')
# Out:
# settings  dict_keys(['settings_version', 'datasets_dir', 'weights_dir', 'runs_dir', 'uuid', 'sync', 'api_key', 'openai_api_key', 'clearml', 'comet', 'dvc', 'hub', 'mlflow', 'neptune', 'raytune', 'tensorboard', 'wandb', 'vscode_msg', 'openvino_msg'])
# datasets_dir  D:/data/ultralytics
# weights_dir  D:/results/yolov11_pose/predict\checkpoints
# runs_dir  D:/results/yolov11_pose/predict

# %%
dataset=check_det_dataset("coco8-seg.yaml")
# Out:
# WARNING Dataset 'coco8-seg.yaml' images not found, missing path 'D:\data\ultralytics\coco8-seg\images\val'
# Downloading https://ultralytics.com/assets/coco8-seg.zip to 'D:\data\ultralytics\coco8-seg.zip': 100% ━━━━━━━━━━━━ 439.3KB 2.4MB/s 0.2s/s 0.1s<1.1s
# Unzipping D:\data\ultralytics\coco8-seg.zip to D:\data\ultralytics\coco8-seg...: 100% ━━━━━━━━━━━━ 25/25 280.2files/s 0.1s
# Dataset download success  (1.7s), saved to D:\data\ultralytics
