# %%
import torchvision

root='D:/data/kinetics'

# train_dataset=torchvision.datasets.Kinetics(root=f'{root}/kinetics400-train', frames_per_clip=16, num_classes='400', split='train', 
#                                             step_between_clips=16, transform=None, extensions=('mp4',), 
#                                             download=True, num_download_workers= 1, num_workers= 1)
val_dataset=torchvision.datasets.Kinetics(root=f'{root}/kinetics400-val', frames_per_clip=16, num_classes='400', split='val', 
                                            step_between_clips=8, transform=None, extensions=('mp4',), 
                                            download=True, num_download_workers= 1, num_workers= 1) # step_between_clips=8 for denser evaluation
# Out:
# 100%|█████████████████████████████████████████████| 1243/1243 [1:58:34<00:00,  5.72s/it]
# C:\Users\Sureerat\miniforge3\envs\pytorchvideo\lib\site-packages\torchvision\datasets\video_utils.py:219: UserWarning: There aren't enough frames in the current video to get a clip for the given clip length and frames between clips. The video (and potentially others) will be skipped.
#   warnings.warn(
