# %%
import os
from pathlib import Path

import numpy as np

import sys
sys.path.append('../../../')

# %load_ext autoreload
# %autoreload 2

from computer_vision.torch_video.utils.plotting import plot_all

# %%
csv=Path(r'D:\results\ucf101\train\result.csv')

plot_all(csv)
