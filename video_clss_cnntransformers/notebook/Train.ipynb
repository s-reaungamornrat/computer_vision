# %%
# %matplotlib inline

import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE" # tells OpenMP to not complain if it notices that two copies of OpenMP are loaded.

from IPython.display import Video
from IPython.display import Audio as play_audio
from torchvision.utils import make_grid
from torchcodec.encoders import VideoEncoder

def play_video(encoded_bytes):
    return Video(data=encoded_bytes.numpy().tobytes(),
                embed=True, width=640, height=360, mimetype="video/mp4")

import matplotlib.pyplot as plt

import sys
sys.path.append('../../../')

# %%
import time
import warnings
import datetime
from pathlib import Path

import torch
import torch.nn as nn
import torchvision

# %load_ext autoreload
# %autoreload 2


from computer_vision.torch_video.parameter_parser import parser
from computer_vision.torch_video.trainer import Trainer

# %%
data_dirpath=Path('D:/data/UCF101')
root=data_dirpath/'UCF-101'
annotation_path=data_dirpath/'UCF101TrainTestSplits-RecognitionTask'
framerate=4
metadata_path=data_dirpath/f'metadata_framerate{framerate}.pt'

mini_train=True
if not mini_train:
    output_dirpath=Path('D:/results/ucf101/cnn_tfm_pretrained/train') 
    arguments= f"""-d {root} -a {annotation_path} -m {metadata_path} -o {output_dirpath} 
    --model resnet50-tfm --data-fold 1 --frame-rate {framerate} --clip-duration 2 --step-duration 1.7 
    --num-ffmpeg-threads 16 --batch-size 16 --nbs 64 --lr 0.005 --momentum 0.9 --warmup_momentum 0.85
    --print-freq 100 --plot-freq 5 --time 24 --epochs 200 
    --device cuda
    """ # --use-cutmix-mixup
else:
    output_dirpath=Path('D:/results/ucf101/cnn_tfm_pretrained/mini_train') 
    arguments= f"""-d {root} -a {annotation_path} -m {metadata_path} -o {output_dirpath}
    --model resnet50-tfm --data-fold 1 --frame-rate {framerate} --clip-duration 2 --step-duration 1.7 
    --num-ffmpeg-threads 16 --batch-size 16 --nbs 64  --lr 0.005 --momentum 0.9 --warmup_momentum 0.85
    --print-freq 2 --plot-freq 2 --time 14  --n-batches 4 --epochs 3
    --device cuda
    """ # --use-cutmix-mixup --time 18
args=parser.parse_args(arguments.split())
trainer=Trainer(args)
trainer.train()
# Out:
# Not using distributed mode
#
# 'optimizer:' AdamW(lr=9.9e-05, momentum=0.9) with parameter groups 59 weight(weight_decay=0.), 68 weight(weight_decay=0.0005), 73 bias(weight_decay=0.)
# Resume training from epoch 2 with best_acc at 0.0 based on checkpoint D:\results\ucf101\cnn_tfm_pretrained\mini_train\checkpoint\last.pth
# Start training
# Epoch: [2] [   0/1902] eta: 9:30:36 lr0: 8.415e-06 lr1: 8.415e-06 lr2: 8.415e-06 clips/s: 0.945 loss: 4.6877 (4.6877) acc1: 0.0000 (0.0000) acc5: 12.5000 (12.5000) time: 0.9000 data: 0.0537 max mem: 7611
